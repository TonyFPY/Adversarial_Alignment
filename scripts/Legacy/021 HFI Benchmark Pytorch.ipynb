# %%
# !git clone https://github.com/bethgelab/model-vs-human.git
# Out:
# Cloning into 'model-vs-human'...
# remote: Enumerating objects: 733, done.
# remote: Counting objects: 100% (225/225), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 733 (delta 163), reused 141 (delta 140), pack-reused 508
# Receiving objects: 100% (733/733), 27.05 MiB | 12.13 MiB/s, done.
# Resolving deltas: 100% (333/333), done.

# %%
import cv2
import numpy as np
import tensorflow as tf
import torch
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

from google.colab import drive
drive.mount('/content/drive')


import pandas as pd


from google.colab import auth

auth.authenticate_user()

project_id = 'beyond-dl-1503610372419'
# !gcloud config set project {project_id}

# !pip install -q git+https://github.com/openai/CLIP#egg=CLIP
# !pip install -q pytorch_pretrained_vit
# !pip install git+https://github.com/bethgelab/model-vs-human --no-deps
# !pip install git+https://github.com/bethgelab/model-vs-human --no-deps

# !pip install -q captum
import captum
from captum.attr import LayerGradCam 


def set_size(w,h):
  """Set matplot figure size"""
  plt.rcParams["figure.figsize"] = [w,h]

def show(img, p=False, smooth=False, **kwargs):
  """ Display torch/tf tensor """ 
  try:
    img = img.detach().cpu()
  except:
    img = np.array(img)
  
  img = np.array(img, dtype=np.float32)

  # check if channel first
  if img.shape[0] == 1:
    img = img[0]
  elif img.shape[0] == 3:
    img = np.moveaxis(img, 0, -1)
  # check if cmap
  if img.shape[-1] == 1:
    img = img[:,:,0]
  # normalize
  if img.max() > 1 or img.min() < 0:
    img -= img.min(); img/=img.max()
  # check if clip percentile
  if p is not False:
    img = np.clip(img, np.percentile(img, p), np.percentile(img, 100-p))
  
  if smooth and len(img.shape) == 2:
    img = gaussian_filter(img, smooth)

  plt.imshow(img, **kwargs)
  plt.axis('off')
  plt.grid(None)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Updated property [core/project].
# Collecting git+https://github.com/bethgelab/model-vs-human
#   Cloning https://github.com/bethgelab/model-vs-human to /tmp/pip-req-build-m3kufyee
#   Running command git clone -q https://github.com/bethgelab/model-vs-human /tmp/pip-req-build-m3kufyee
# Collecting git+https://github.com/bethgelab/model-vs-human
#   Cloning https://github.com/bethgelab/model-vs-human to /tmp/pip-req-build-072yc85r
#   Running command git clone -q https://github.com/bethgelab/model-vs-human /tmp/pip-req-build-072yc85r

# %%
try:
  import modelvshuman
except:
  pass

import modelvshuman
from modelvshuman import models

print(models.list_models("pytorch"))
print(models.list_models("tensorflow"))

for m in models.list_models("pytorch"):
  print(m)
# Out:
# ['resnet50_trained_on_SIN', 'resnet50_trained_on_SIN_and_IN', 'resnet50_trained_on_SIN_and_IN_then_finetuned_on_IN', 'bagnet9', 'bagnet17', 'bagnet33', 'simclr_resnet50x1_supervised_baseline', 'simclr_resnet50x4_supervised_baseline', 'simclr_resnet50x1', 'simclr_resnet50x2', 'simclr_resnet50x4', 'InsDis', 'MoCo', 'MoCoV2', 'PIRL', 'InfoMin', 'resnet50_l2_eps0', 'resnet50_l2_eps0_01', 'resnet50_l2_eps0_03', 'resnet50_l2_eps0_05', 'resnet50_l2_eps0_1', 'resnet50_l2_eps0_25', 'resnet50_l2_eps0_5', 'resnet50_l2_eps1', 'resnet50_l2_eps3', 'resnet50_l2_eps5', 'efficientnet_b0', 'efficientnet_es', 'efficientnet_b0_noisy_student', 'efficientnet_l2_noisy_student_475', 'transformer_B16_IN21K', 'transformer_B32_IN21K', 'transformer_L16_IN21K', 'transformer_L32_IN21K', 'vit_small_patch16_224', 'vit_base_patch16_224', 'vit_large_patch16_224', 'cspresnet50', 'cspresnext50', 'cspdarknet53', 'darknet53', 'dpn68', 'dpn68b', 'dpn92', 'dpn98', 'dpn131', 'dpn107', 'hrnet_w18_small', 'hrnet_w18_small', 'hrnet_w18_small_v2', 'hrnet_w18', 'hrnet_w30', 'hrnet_w40', 'hrnet_w44', 'hrnet_w48', 'hrnet_w64', 'selecsls42', 'selecsls84', 'selecsls42b', 'selecsls60', 'selecsls60b', 'clip', 'clipRN50', 'resnet50_swsl', 'ResNeXt101_32x16d_swsl', 'BiTM_resnetv2_50x1', 'BiTM_resnetv2_50x3', 'BiTM_resnetv2_101x1', 'BiTM_resnetv2_101x3', 'BiTM_resnetv2_152x2', 'BiTM_resnetv2_152x4', 'resnet50_clip_hard_labels', 'resnet50_clip_soft_labels', 'swag_regnety_16gf_in1k', 'swag_regnety_32gf_in1k', 'swag_regnety_128gf_in1k', 'swag_vit_b16_in1k', 'swag_vit_l16_in1k', 'swag_vit_h14_in1k']
# ['efficientnet_b0', 'resnet50', 'mobilenet_v1', 'inception_v1']
# resnet50_trained_on_SIN
# resnet50_trained_on_SIN_and_IN
# resnet50_trained_on_SIN_and_IN_then_finetuned_on_IN
# bagnet9
# bagnet17
# bagnet33
# simclr_resnet50x1_supervised_baseline
# simclr_resnet50x4_supervised_baseline
# simclr_resnet50x1
# simclr_resnet50x2
# simclr_resnet50x4
# InsDis
# MoCo
# MoCoV2
# PIRL
# InfoMin
# resnet50_l2_eps0
# resnet50_l2_eps0_01
# resnet50_l2_eps0_03
# resnet50_l2_eps0_05
# resnet50_l2_eps0_1
# resnet50_l2_eps0_25
# resnet50_l2_eps0_5
# resnet50_l2_eps1
# resnet50_l2_eps3
# resnet50_l2_eps5
# efficientnet_b0
# efficientnet_es
# efficientnet_b0_noisy_student
# efficientnet_l2_noisy_student_475
# transformer_B16_IN21K
# transformer_B32_IN21K
# transformer_L16_IN21K
# transformer_L32_IN21K
# vit_small_patch16_224
# vit_base_patch16_224
# vit_large_patch16_224
# cspresnet50
# cspresnext50
# cspdarknet53
# darknet53
# dpn68
# dpn68b
# dpn92
# dpn98
# dpn131
# dpn107
# hrnet_w18_small
# hrnet_w18_small
# hrnet_w18_small_v2
# hrnet_w18
# hrnet_w30
# hrnet_w40
# hrnet_w44
# hrnet_w48
# hrnet_w64
# selecsls42
# selecsls84
# selecsls42b
# selecsls60
# selecsls60b
# clip
# clipRN50
# resnet50_swsl
# ResNeXt101_32x16d_swsl
# BiTM_resnetv2_50x1
# BiTM_resnetv2_50x3
# BiTM_resnetv2_101x1
# BiTM_resnetv2_101x3
# BiTM_resnetv2_152x2
# BiTM_resnetv2_152x4
# resnet50_clip_hard_labels
# resnet50_clip_soft_labels
# swag_regnety_16gf_in1k
# swag_regnety_32gf_in1k
# swag_regnety_128gf_in1k
# swag_vit_b16_in1k
# swag_vit_l16_in1k
# swag_vit_h14_in1k

# %%
# !cp "/content/drive/MyDrive/Paper Meta-predictor machine/data/clickme/clickme_val.tfrecords" ./

# %%
AUTO = tf.data.AUTOTUNE
BLUR_KERNEL_SIZE = 10
BLUR_SIGMA = 10

_feature_description = {
      "image"       : tf.io.FixedLenFeature([], tf.string, default_value=''),
      "heatmap"     : tf.io.FixedLenFeature([], tf.string, default_value=''),
      "label"       : tf.io.FixedLenFeature([], tf.int64, default_value=0),
}

def _gaussian_kernel(size, sigma):
  x_range = tf.range(-(size-1)//2, (size-1)//2 + 1, 1)
  y_range = tf.range((size-1)//2, -(size-1)//2 - 1, -1)

  xs, ys = tf.meshgrid(x_range, y_range)
  kernel = tf.exp(-(xs**2 + ys**2)/(2*(sigma**2))) / (2*np.pi*(sigma**2))

  kernel = tf.cast(kernel / tf.reduce_sum(kernel), tf.float32)

  return tf.expand_dims(tf.expand_dims(kernel, axis=-1), axis=-1)

GAUSSIAN_KERNEL = tf.cast(_gaussian_kernel(BLUR_KERNEL_SIZE, BLUR_SIGMA), tf.float32)

def _gaussian_blur(heatmap):
    heatmap = tf.nn.conv2d(heatmap[None, :, :, :], GAUSSIAN_KERNEL, [1, 1, 1, 1], 'SAME')
    #heatmap = tf.nn.conv2d(heatmap, GAUSSIAN_KERNEL, [1, 1, 1, 1], 'SAME')
    #heatmap = tf.nn.conv2d(heatmap, GAUSSIAN_KERNEL, [1, 1, 1, 1], 'SAME')
    return heatmap[0]

def _random_crop(image, heatmap):
  seed = tf.random.uniform([2], maxval=10_000, dtype=tf.int32)
  crop_size = tf.random.uniform([], minval=224, maxval=256, dtype=tf.int32)
  
  cropped_image   = tf.image.stateless_random_crop(image, (crop_size, crop_size, 3), seed=seed)
  cropped_heatmap = tf.image.stateless_random_crop(heatmap, (crop_size, crop_size, 1), seed=seed)

  return cropped_image, cropped_heatmap


def parse_prototype(prototype, training=False):
  data    = tf.io.parse_single_example(prototype, _feature_description)

  image   = tf.io.decode_raw(data['image'], tf.float32)
  image   = tf.reshape(image, (256, 256, 3))
  image   = tf.cast(image, tf.float32)
  
  #heatmap = tf.io.decode_jpeg(data['heatmap'])
  heatmap = tf.io.decode_raw(data['heatmap'], tf.float32)
  heatmap = tf.reshape(heatmap, (256, 256, 1))

  image   = tf.image.resize(image, (224, 224), method='bilinear')
  image   = tf.cast(image, tf.float32)

  heatmap = tf.cast(heatmap, tf.float32)
  heatmap = tf.image.resize(heatmap, (64, 64), method="bilinear")
  heatmap = _gaussian_blur(heatmap)
  heatmap = tf.image.resize(heatmap, (224, 224), method="bilinear")
  heatmap = tf.cast(heatmap, tf.float32)

  label   = tf.cast(data['label'], tf.int32)
  label   = tf.one_hot(label, 1_000)

  return image, heatmap, label

def get_dataset(batch_size, training=False):
    deterministic_order = tf.data.Options()
    deterministic_order.experimental_deterministic = True

    dataset = tf.data.TFRecordDataset(['/content/clickme_val.tfrecords'], num_parallel_reads=AUTO)
    dataset = dataset.with_options(deterministic_order) 
      
    dataset = dataset.map(parse_prototype, num_parallel_calls=AUTO)
    
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(AUTO)

    return dataset

# %%
imagenet_classes = ["tench", "goldfish", "great white shark", "tiger shark", "hammerhead shark", "electric ray", "stingray", "rooster", "hen", "ostrich", "brambling", "goldfinch", "house finch", "junco", "indigo bunting", "American robin", "bulbul", "jay", "magpie", "chickadee", "American dipper", "kite (bird of prey)", "bald eagle", "vulture", "great grey owl", "fire salamander", "smooth newt", "newt", "spotted salamander", "axolotl", "American bullfrog", "tree frog", "tailed frog", "loggerhead sea turtle", "leatherback sea turtle", "mud turtle", "terrapin", "box turtle", "banded gecko", "green iguana", "Carolina anole", "desert grassland whiptail lizard", "agama", "frilled-necked lizard", "alligator lizard", "Gila monster", "European green lizard", "chameleon", "Komodo dragon", "Nile crocodile", "American alligator", "triceratops", "worm snake", "ring-necked snake", "eastern hog-nosed snake", "smooth green snake", "kingsnake", "garter snake", "water snake", "vine snake", "night snake", "boa constrictor", "African rock python", "Indian cobra", "green mamba", "sea snake", "Saharan horned viper", "eastern diamondback rattlesnake", "sidewinder rattlesnake", "trilobite", "harvestman", "scorpion", "yellow garden spider", "barn spider", "European garden spider", "southern black widow", "tarantula", "wolf spider", "tick", "centipede", "black grouse", "ptarmigan", "ruffed grouse", "prairie grouse", "peafowl", "quail", "partridge", "african grey parrot", "macaw", "sulphur-crested cockatoo", "lorikeet", "coucal", "bee eater", "hornbill", "hummingbird", "jacamar", "toucan", "duck", "red-breasted merganser", "goose", "black swan", "tusker", "echidna", "platypus", "wallaby", "koala", "wombat", "jellyfish", "sea anemone", "brain coral", "flatworm", "nematode", "conch", "snail", "slug", "sea slug", "chiton", "chambered nautilus", "Dungeness crab", "rock crab", "fiddler crab", "red king crab", "American lobster", "spiny lobster", "crayfish", "hermit crab", "isopod", "white stork", "black stork", "spoonbill", "flamingo", "little blue heron", "great egret", "bittern bird", "crane bird", "limpkin", "common gallinule", "American coot", "bustard", "ruddy turnstone", "dunlin", "common redshank", "dowitcher", "oystercatcher", "pelican", "king penguin", "albatross", "grey whale", "killer whale", "dugong", "sea lion", "Chihuahua", "Japanese Chin", "Maltese", "Pekingese", "Shih Tzu", "King Charles Spaniel", "Papillon", "toy terrier", "Rhodesian Ridgeback", "Afghan Hound", "Basset Hound", "Beagle", "Bloodhound", "Bluetick Coonhound", "Black and Tan Coonhound", "Treeing Walker Coonhound", "English foxhound", "Redbone Coonhound", "borzoi", "Irish Wolfhound", "Italian Greyhound", "Whippet", "Ibizan Hound", "Norwegian Elkhound", "Otterhound", "Saluki", "Scottish Deerhound", "Weimaraner", "Staffordshire Bull Terrier", "American Staffordshire Terrier", "Bedlington Terrier", "Border Terrier", "Kerry Blue Terrier", "Irish Terrier", "Norfolk Terrier", "Norwich Terrier", "Yorkshire Terrier", "Wire Fox Terrier", "Lakeland Terrier", "Sealyham Terrier", "Airedale Terrier", "Cairn Terrier", "Australian Terrier", "Dandie Dinmont Terrier", "Boston Terrier", "Miniature Schnauzer", "Giant Schnauzer", "Standard Schnauzer", "Scottish Terrier", "Tibetan Terrier", "Australian Silky Terrier", "Soft-coated Wheaten Terrier", "West Highland White Terrier", "Lhasa Apso", "Flat-Coated Retriever", "Curly-coated Retriever", "Golden Retriever", "Labrador Retriever", "Chesapeake Bay Retriever", "German Shorthaired Pointer", "Vizsla", "English Setter", "Irish Setter", "Gordon Setter", "Brittany dog", "Clumber Spaniel", "English Springer Spaniel", "Welsh Springer Spaniel", "Cocker Spaniel", "Sussex Spaniel", "Irish Water Spaniel", "Kuvasz", "Schipperke", "Groenendael dog", "Malinois", "Briard", "Australian Kelpie", "Komondor", "Old English Sheepdog", "Shetland Sheepdog", "collie", "Border Collie", "Bouvier des Flandres dog", "Rottweiler", "German Shepherd Dog", "Dobermann", "Miniature Pinscher", "Greater Swiss Mountain Dog", "Bernese Mountain Dog", "Appenzeller Sennenhund", "Entlebucher Sennenhund", "Boxer", "Bullmastiff", "Tibetan Mastiff", "French Bulldog", "Great Dane", "St. Bernard", "husky", "Alaskan Malamute", "Siberian Husky", "Dalmatian", "Affenpinscher", "Basenji", "pug", "Leonberger", "Newfoundland dog", "Great Pyrenees dog", "Samoyed", "Pomeranian", "Chow Chow", "Keeshond", "brussels griffon", "Pembroke Welsh Corgi", "Cardigan Welsh Corgi", "Toy Poodle", "Miniature Poodle", "Standard Poodle", "Mexican hairless dog (xoloitzcuintli)", "grey wolf", "Alaskan tundra wolf", "red wolf or maned wolf", "coyote", "dingo", "dhole", "African wild dog", "hyena", "red fox", "kit fox", "Arctic fox", "grey fox", "tabby cat", "tiger cat", "Persian cat", "Siamese cat", "Egyptian Mau", "cougar", "lynx", "leopard", "snow leopard", "jaguar", "lion", "tiger", "cheetah", "brown bear", "American black bear", "polar bear", "sloth bear", "mongoose", "meerkat", "tiger beetle", "ladybug", "ground beetle", "longhorn beetle", "leaf beetle", "dung beetle", "rhinoceros beetle", "weevil", "fly", "bee", "ant", "grasshopper", "cricket insect", "stick insect", "cockroach", "praying mantis", "cicada", "leafhopper", "lacewing", "dragonfly", "damselfly", "red admiral butterfly", "ringlet butterfly", "monarch butterfly", "small white butterfly", "sulphur butterfly", "gossamer-winged butterfly", "starfish", "sea urchin", "sea cucumber", "cottontail rabbit", "hare", "Angora rabbit", "hamster", "porcupine", "fox squirrel", "marmot", "beaver", "guinea pig", "common sorrel horse", "zebra", "pig", "wild boar", "warthog", "hippopotamus", "ox", "water buffalo", "bison", "ram (adult male sheep)", "bighorn sheep", "Alpine ibex", "hartebeest", "impala (antelope)", "gazelle", "arabian camel", "llama", "weasel", "mink", "European polecat", "black-footed ferret", "otter", "skunk", "badger", "armadillo", "three-toed sloth", "orangutan", "gorilla", "chimpanzee", "gibbon", "siamang", "guenon", "patas monkey", "baboon", "macaque", "langur", "black-and-white colobus", "proboscis monkey", "marmoset", "white-headed capuchin", "howler monkey", "titi monkey", "Geoffroy's spider monkey", "common squirrel monkey", "ring-tailed lemur", "indri", "Asian elephant", "African bush elephant", "red panda", "giant panda", "snoek fish", "eel", "silver salmon", "rock beauty fish", "clownfish", "sturgeon", "gar fish", "lionfish", "pufferfish", "abacus", "abaya", "academic gown", "accordion", "acoustic guitar", "aircraft carrier", "airliner", "airship", "altar", "ambulance", "amphibious vehicle", "analog clock", "apiary", "apron", "trash can", "assault rifle", "backpack", "bakery", "balance beam", "balloon", "ballpoint pen", "Band-Aid", "banjo", "baluster / handrail", "barbell", "barber chair", "barbershop", "barn", "barometer", "barrel", "wheelbarrow", "baseball", "basketball", "bassinet", "bassoon", "swimming cap", "bath towel", "bathtub", "station wagon", "lighthouse", "beaker", "military hat (bearskin or shako)", "beer bottle", "beer glass", "bell tower", "baby bib", "tandem bicycle", "bikini", "ring binder", "binoculars", "birdhouse", "boathouse", "bobsleigh", "bolo tie", "poke bonnet", "bookcase", "bookstore", "bottle cap", "hunting bow", "bow tie", "brass memorial plaque", "bra", "breakwater", "breastplate", "broom", "bucket", "buckle", "bulletproof vest", "high-speed train", "butcher shop", "taxicab", "cauldron", "candle", "cannon", "canoe", "can opener", "cardigan", "car mirror", "carousel", "tool kit", "cardboard box / carton", "car wheel", "automated teller machine", "cassette", "cassette player", "castle", "catamaran", "CD player", "cello", "mobile phone", "chain", "chain-link fence", "chain mail", "chainsaw", "storage chest", "chiffonier", "bell or wind chime", "china cabinet", "Christmas stocking", "church", "movie theater", "cleaver", "cliff dwelling", "cloak", "clogs", "cocktail shaker", "coffee mug", "coffeemaker", "spiral or coil", "combination lock", "computer keyboard", "candy store", "container ship", "convertible", "corkscrew", "cornet", "cowboy boot", "cowboy hat", "cradle", "construction crane", "crash helmet", "crate", "infant bed", "Crock Pot", "croquet ball", "crutch", "cuirass", "dam", "desk", "desktop computer", "rotary dial telephone", "diaper", "digital clock", "digital watch", "dining table", "dishcloth", "dishwasher", "disc brake", "dock", "dog sled", "dome", "doormat", "drilling rig", "drum", "drumstick", "dumbbell", "Dutch oven", "electric fan", "electric guitar", "electric locomotive", "entertainment center", "envelope", "espresso machine", "face powder", "feather boa", "filing cabinet", "fireboat", "fire truck", "fire screen", "flagpole", "flute", "folding chair", "football helmet", "forklift", "fountain", "fountain pen", "four-poster bed", "freight car", "French horn", "frying pan", "fur coat", "garbage truck", "gas mask or respirator", "gas pump", "goblet", "go-kart", "golf ball", "golf cart", "gondola", "gong", "gown", "grand piano", "greenhouse", "radiator grille", "grocery store", "guillotine", "hair clip", "hair spray", "half-track", "hammer", "hamper", "hair dryer", "hand-held computer", "handkerchief", "hard disk drive", "harmonica", "harp", "combine harvester", "hatchet", "holster", "home theater", "honeycomb", "hook", "hoop skirt", "gymnastic horizontal bar", "horse-drawn vehicle", "hourglass", "iPod", "clothes iron", "carved pumpkin", "jeans", "jeep", "T-shirt", "jigsaw puzzle", "rickshaw", "joystick", "kimono", "knee pad", "knot", "lab coat", "ladle", "lampshade", "laptop computer", "lawn mower", "lens cap", "letter opener", "library", "lifeboat", "lighter", "limousine", "ocean liner", "lipstick", "slip-on shoe", "lotion", "music speaker", "loupe magnifying glass", "sawmill", "magnetic compass", "messenger bag", "mailbox", "tights", "one-piece bathing suit", "manhole cover", "maraca", "marimba", "mask", "matchstick", "maypole", "maze", "measuring cup", "medicine cabinet", "megalith", "microphone", "microwave oven", "military uniform", "milk can", "minibus", "miniskirt", "minivan", "missile", "mitten", "mixing bowl", "mobile home", "ford model t", "modem", "monastery", "monitor", "moped", "mortar and pestle", "graduation cap", "mosque", "mosquito net", "vespa", "mountain bike", "tent", "computer mouse", "mousetrap", "moving van", "muzzle", "metal nail", "neck brace", "necklace", "baby pacifier", "notebook computer", "obelisk", "oboe", "ocarina", "odometer", "oil filter", "pipe organ", "oscilloscope", "overskirt", "bullock cart", "oxygen mask", "product packet / packaging", "paddle", "paddle wheel", "padlock", "paintbrush", "pajamas", "palace", "pan flute", "paper towel", "parachute", "parallel bars", "park bench", "parking meter", "railroad car", "patio", "payphone", "pedestal", "pencil case", "pencil sharpener", "perfume", "Petri dish", "photocopier", "plectrum", "Pickelhaube", "picket fence", "pickup truck", "pier", "piggy bank", "pill bottle", "pillow", "ping-pong ball", "pinwheel", "pirate ship", "drink pitcher", "block plane", "planetarium", "plastic bag", "plate rack", "farm plow", "plunger", "Polaroid camera", "pole", "police van", "poncho", "pool table", "soda bottle", "plant pot", "potter's wheel", "power drill", "prayer rug", "printer", "prison", "missile", "projector", "hockey puck", "punching bag", "purse", "quill", "quilt", "race car", "racket", "radiator", "radio", "radio telescope", "rain barrel", "recreational vehicle", "fishing casting reel", "reflex camera", "refrigerator", "remote control", "restaurant", "revolver", "rifle", "rocking chair", "rotisserie", "eraser", "rugby ball", "ruler measuring stick", "sneaker", "safe", "safety pin", "salt shaker", "sandal", "sarong", "saxophone", "scabbard", "weighing scale", "school bus", "schooner", "scoreboard", "CRT monitor", "screw", "screwdriver", "seat belt", "sewing machine", "shield", "shoe store", "shoji screen / room divider", "shopping basket", "shopping cart", "shovel", "shower cap", "shower curtain", "ski", "balaclava ski mask", "sleeping bag", "slide rule", "sliding door", "slot machine", "snorkel", "snowmobile", "snowplow", "soap dispenser", "soccer ball", "sock", "solar thermal collector", "sombrero", "soup bowl", "keyboard space bar", "space heater", "space shuttle", "spatula", "motorboat", "spider web", "spindle", "sports car", "spotlight", "stage", "steam locomotive", "through arch bridge", "steel drum", "stethoscope", "scarf", "stone wall", "stopwatch", "stove", "strainer", "tram", "stretcher", "couch", "stupa", "submarine", "suit", "sundial", "sunglasses", "sunglasses", "sunscreen", "suspension bridge", "mop", "sweatshirt", "swim trunks / shorts", "swing", "electrical switch", "syringe", "table lamp", "tank", "tape player", "teapot", "teddy bear", "television", "tennis ball", "thatched roof", "front curtain", "thimble", "threshing machine", "throne", "tile roof", "toaster", "tobacco shop", "toilet seat", "torch", "totem pole", "tow truck", "toy store", "tractor", "semi-trailer truck", "tray", "trench coat", "tricycle", "trimaran", "tripod", "triumphal arch", "trolleybus", "trombone", "hot tub", "turnstile", "typewriter keyboard", "umbrella", "unicycle", "upright piano", "vacuum cleaner", "vase", "vaulted or arched ceiling", "velvet fabric", "vending machine", "vestment", "viaduct", "violin", "volleyball", "waffle iron", "wall clock", "wallet", "wardrobe", "military aircraft", "sink", "washing machine", "water bottle", "water jug", "water tower", "whiskey jug", "whistle", "hair wig", "window screen", "window shade", "Windsor tie", "wine bottle", "airplane wing", "wok", "wooden spoon", "wool", "split-rail fence", "shipwreck", "sailboat", "yurt", "website", "comic book", "crossword", "traffic or street sign", "traffic light", "dust jacket", "menu", "plate", "guacamole", "consomme", "hot pot", "trifle", "ice cream", "popsicle", "baguette", "bagel", "pretzel", "cheeseburger", "hot dog", "mashed potatoes", "cabbage", "broccoli", "cauliflower", "zucchini", "spaghetti squash", "acorn squash", "butternut squash", "cucumber", "artichoke", "bell pepper", "cardoon", "mushroom", "Granny Smith apple", "strawberry", "orange", "lemon", "fig", "pineapple", "banana", "jackfruit", "cherimoya (custard apple)", "pomegranate", "hay", "carbonara", "chocolate syrup", "dough", "meatloaf", "pizza", "pot pie", "burrito", "red wine", "espresso", "tea cup", "eggnog", "mountain", "bubble", "cliff", "coral reef", "geyser", "lakeshore", "promontory", "sandbar", "beach", "valley", "volcano", "baseball player", "bridegroom", "scuba diver", "rapeseed", "daisy", "yellow lady's slipper", "corn", "acorn", "rose hip", "horse chestnut seed", "coral fungus", "agaric", "gyromitra", "stinkhorn mushroom", "earth star fungus", "hen of the woods mushroom", "bolete", "corn cob", "toilet paper"]
imagenet_templates = [
    'a bad photo of a {}.',
    'a photo of many {}.',
    'a sculpture of a {}.',
    'a photo of the hard to see {}.',
    'a low resolution photo of the {}.',
    'a rendering of a {}.',
    'graffiti of a {}.',
    'a bad photo of the {}.',
    'a cropped photo of the {}.',
    'a tattoo of a {}.',
    'the embroidered {}.',
    'a photo of a hard to see {}.',
    'a bright photo of a {}.',
    'a photo of a clean {}.',
    'a photo of a dirty {}.',
    'a dark photo of the {}.',
    'a drawing of a {}.',
    'a photo of my {}.',
    'the plastic {}.',
    'a photo of the cool {}.',
    'a close-up photo of a {}.',
    'a black and white photo of the {}.',
    'a painting of the {}.',
    'a painting of a {}.',
    'a pixelated photo of the {}.',
    'a sculpture of the {}.',
    'a bright photo of the {}.',
    'a cropped photo of a {}.',
    'a plastic {}.',
    'a photo of the dirty {}.',
    'a jpeg corrupted photo of a {}.',
    'a blurry photo of the {}.',
    'a photo of the {}.',
    'a good photo of the {}.',
    'a rendering of the {}.',
    'a {} in a video game.',
    'a photo of one {}.',
    'a doodle of a {}.',
    'a close-up photo of the {}.',
    'a photo of a {}.',
    'the origami {}.',
    'the {} in a video game.',
    'a sketch of a {}.',
    'a doodle of the {}.',
    'a origami {}.',
    'a low resolution photo of a {}.',
    'the toy {}.',
    'a rendition of the {}.',
    'a photo of the clean {}.',
    'a photo of a large {}.',
    'a rendition of a {}.',
    'a photo of a nice {}.',
    'a photo of a weird {}.',
    'a blurry photo of a {}.',
    'a cartoon {}.',
    'art of a {}.',
    'a sketch of the {}.',
    'a embroidered {}.',
    'a pixelated photo of a {}.',
    'itap of the {}.',
    'a jpeg corrupted photo of the {}.',
    'a good photo of a {}.',
    'a plushie {}.',
    'a photo of the nice {}.',
    'a photo of the small {}.',
    'a photo of the weird {}.',
    'the cartoon {}.',
    'art of the {}.',
    'a drawing of the {}.',
    'a photo of the large {}.',
    'a black and white photo of a {}.',
    'the plushie {}.',
    'a dark photo of a {}.',
    'itap of a {}.',
    'graffiti of the {}.',
    'a toy {}.',
    'itap of my {}.',
    'a photo of a cool {}.',
    'a photo of a small {}.',
    'a tattoo of the {}.',
]

print(f"{len(imagenet_classes)} classes, {len(imagenet_templates)} templates")
# Out:
# 1000 classes, 80 templates

# %%
# TEstingCLIP
! pip install ftfy regex tqdm
! pip install git+https://github.com/openai/CLIP.git
import numpy as np
import torch
import clip
from tqdm.notebook import tqdm
from pkg_resources import packaging

print("Torch version:", torch.__version__)
model, preprocess = clip.load("RN50")
input_resolution = model.visual.input_resolution
context_length = model.context_length
vocab_size = model.vocab_size

print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
print("Input resolution:", input_resolution)
print("Context length:", context_length)
print("Vocab size:", vocab_size)
# Out:
# Requirement already satisfied: ftfy in /usr/local/lib/python3.7/dist-packages (6.1.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (2019.12.20)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.64.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy) (0.2.5)
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-g3yo_ii9
#   Running command git clone -q https://github.com/openai/CLIP.git /tmp/pip-req-build-g3yo_ii9
# Requirement already satisfied: ftfy in /usr/local/lib/python3.7/dist-packages (from clip==1.0) (6.1.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from clip==1.0) (2019.12.20)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from clip==1.0) (4.64.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from clip==1.0) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from clip==1.0) (0.12.0+cu113)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy->clip==1.0) (0.2.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->clip==1.0) (4.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->clip==1.0) (2.23.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->clip==1.0) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->clip==1.0) (1.21.6)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->clip==1.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->clip==1.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->clip==1.0) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->clip==1.0) (3.0.4)
# Torch version: 1.11.0+cu113
# Model parameters: 102,007,137
# Input resolution: 224
# Context length: 77
# Vocab size: 49408

# %%
def zeroshot_classifier(classnames, templates,model):
    with torch.no_grad():
        zeroshot_weights = []
        for classname in tqdm(classnames):
            texts = [template.format(classname) for template in templates] #format with class
            texts = clip.tokenize(texts).cuda() #tokenize
            class_embeddings = model.encode_text(texts) #embed with text encoder
            class_embeddings /= class_embeddings.norm(dim=-1, keepdim=True)
            class_embedding = class_embeddings.mean(dim=0)
            class_embedding /= class_embedding.norm()
            zeroshot_weights.append(class_embedding)
        zeroshot_weights = torch.stack(zeroshot_weights, dim=1).cuda()
    return zeroshot_weights


#zeroshot_weights = zeroshot_classifier(imagenet_classes, imagenet_templates,model)

# %%
zeroshot_weights.cuda()
model.cuda()
with torch.no_grad():
  ds = get_dataset(120, True)
  imgs=0
  for xb, hb, yb in ds:
    #imgs+=120
    #print(imgs)
    for x,h,y in zip(xb,hb,yb):
      print(x.dtype, y.dtype, x.shape)
      x = tf.cast(x, tf.float32).numpy()
      x -= x.min()
      x /= x.max()
      x = np.array([x])
      x_ = x.transpose(0,3,1,2)
      x_ = torch.tensor(x_).cuda()
      
      image_features = model.encode_image(x_)
      image_features /= image_features.norm(dim=-1, keepdim=True)
      logits = 100. * image_features @ zeroshot_weights
      pred = np.argmax(logits.cpu().numpy())
      h = tf.cast(h, tf.float32).numpy()
      label = np.argmax(y)
      show(x)
      show(h, cmap='jet', alpha=0.3)
      plt.title(f"{h.shape} H({h.mean()} {h.std()}), X({x.min()} {x.max()}) gt {imagenet_classes[label]}label {imagenet_classes[pred]}")
      plt.axis('off')
      
      plt.show()
      print('\n\n\n')

# %%
ds = get_dataset(120, True)
imgs=0
for xb, hb, yb in ds:
  #imgs+=120
  #print(imgs)
  for x,h,y in zip(xb,hb,yb):
    print(x.dtype, y.dtype, x.shape)
    x = tf.cast(x, tf.float32).numpy()
    x -= x.min()
    x /= x.max()
  
    h = tf.cast(h, tf.float32).numpy()
  
    show(x)
    show(h, cmap='jet', alpha=0.3)
    print(imagenet_classes[np.argmax(y)])
    plt.title(f"{h.shape} H({h.mean()} {h.std()}), X({x.min()} {x.max()})")
    plt.axis('off')
    plt.show()
    print('\n\n\n')
    break
  break
# Out:
# <dtype: 'float32'> <dtype: 'float32'> (224, 224, 3)
# Cocker Spaniel

# %%
import time
from scipy.stats import spearmanr

DEBUG = False

def spearmanr_sim(explanations1, explanations2, reducers = [1, 4, 16]):
  sims = {k: [] for k in reducers}

  if explanations1.shape[-1] != 1:
    explanations1 = explanations1[:,:,:,None]
  if explanations2.shape[-1] != 1:
    explanations2 = explanations2[:,:,:,None]

  explanations1 = tf.cast(explanations1, tf.float32).numpy()
  explanations2 = tf.cast(explanations2, tf.float32).numpy()

  for reducer in reducers:
    sz = int(explanations1.shape[1] / reducer)
    explanations1_resize = tf.image.resize(explanations1, (sz, sz)).numpy()
    explanations2_resize = tf.image.resize(explanations2, (sz, sz)).numpy()

    
    if DEBUG:
      plt.subplot(1, 2, 1)
      show(explanations1_resize[0])
      plt.subplot(1, 2, 2)
      show(explanations2_resize[0])
      plt.show()
    
    for x1, x2 in zip(explanations1_resize, explanations2_resize):
        rho, _ = spearmanr(x1.flatten(), x2.flatten())
        sims[reducer].append(rho)

  return sims

def dice(explanations1, explanations2, reducers = [1, 4, 16], p = 10):
  dice_scores = {k: [] for k in reducers}

  if explanations1.shape[-1] != 1:
    explanations1 = explanations1[:,:,:,None]
  if explanations2.shape[-1] != 1:
    explanations2 = explanations2[:,:,:,None]

  explanations1 = tf.cast(explanations1, tf.float32).numpy()
  explanations2 = tf.cast(explanations2, tf.float32).numpy()

  for reducer in reducers:
    sz = int(explanations1.shape[1] / reducer)
    explanations1_resize = tf.image.resize(explanations1, (sz, sz)).numpy()
    explanations2_resize = tf.image.resize(explanations2, (sz, sz)).numpy()

    for j, (x1, x2) in enumerate(zip(explanations1_resize, explanations2_resize)):
      x1 = x1 > np.percentile(x1, 100-p, (0, 1))
      x2 = x2 > np.percentile(x2, 100-p, (0, 1))

      dice_score = 2.0 * np.sum(x1 * x2) / np.sum(x1 + x2)
      dice_scores[reducer].append(dice_score)
      
      if DEBUG and j == 0:
        plt.subplot(1, 2, 1)
        show(x1)
        plt.subplot(1, 2, 2)
        show(x2)
        plt.title(dice_score)
        plt.show()
  
  return dice_scores

def iou(explanations1, explanations2, reducers = [1, 4, 16], p = 10):
  iou_scores = {k: [] for k in reducers}

  if explanations1.shape[-1] != 1:
    explanations1 = explanations1[:,:,:,None]
  if explanations2.shape[-1] != 1:
    explanations2 = explanations2[:,:,:,None]

  explanations1 = tf.cast(explanations1, tf.float32).numpy()
  explanations2 = tf.cast(explanations2, tf.float32).numpy()

  for reducer in reducers:
    sz = int(explanations1.shape[1] / reducer)
    explanations1_resize = tf.image.resize(explanations1, (sz, sz)).numpy()
    explanations2_resize = tf.image.resize(explanations2, (sz, sz)).numpy()

    for j, (x1, x2) in enumerate(zip(explanations1_resize, explanations2_resize)):
      x1 = x1 > np.percentile(x1, 100-p, (0, 1))
      x2 = x2 > np.percentile(x2, 100-p, (0, 1))

      iou_inter = np.sum(np.logical_and(x1, x2))
      iou_union = np.sum(np.logical_or(x1, x2))

      iou_score = iou_inter / iou_union

      iou_scores[reducer].append(iou_score)
      
      if DEBUG and j == 0:
        plt.subplot(1, 2, 1)
        show(x1)
        plt.subplot(1, 2, 2)
        show(x2)
        plt.title(dice_score)
        plt.show()
  
  return iou_scores

# %%
import modelvshuman
from modelvshuman import models
from modelvshuman.models.wrappers.pytorch import ClipPytorchModel
from modelvshuman.models.pytorch.clip.imagenet_classes import imagenet_classes
from modelvshuman.models.pytorch.clip.imagenet_templates import imagenet_templates
zoo = modelvshuman.models.pytorch.model_zoo
#model_name = 'clip'
#model = getattr(zoo, model_name)(model_name)

# %%
from torch import autograd

def saliency(model, x, y_ohe,clip=False,zsw=None):
  #import pdb;pdb.set_trace()
  x.require_grad = True
  x.retain_grad()
 
  if clip:
    
    image_features = model.encode_image(x)
    image_features = image_features/image_features.norm(dim=-1, keepdim=True)
    logits = 100.*image_features@zsw
   
    #logits = model.forward_batch(x)
    y_pred = torch.sum(logits * y_ohe)
  else:
    inputs = model(x)
    y_pred = torch.sum(inputs * y_ohe)
  y_pred.backward()
  phi = x.grad
  
  return phi

def input_gradient(model, x, y):
  return saliency(model, x, y) * x

def smoothgrad(model, x, y, nb_samples=50, sigma=0.2):
  x_noisy = x.unsqueeze(1)
  x_noisy = x_noisy.repeat(1, nb_samples, 1, 1, 1)

  epsilon = torch.normal(torch.zeros(1, nb_samples, *x_noisy.shape[2:]), sigma).cuda()
  x_noisy = x_noisy + epsilon

  y_noisy = y.unsqueeze(1)
  y_noisy = y_noisy.repeat(1, nb_samples)

  sgs = None
  for i in range(len(x)):
    sg = torch.mean(saliency(model, x_noisy[i], y_noisy[i]), 0, keepdim=True)
    sgs = torch.cat([sgs, sg], 0) if sgs is not None else sg
  
  return sgs

def integrad(model, x, y, nb_samples=50):
  alphas = torch.linspace(0.0, 1.0, nb_samples)[None, :, None, None, None].cuda()

  x_integrated = x.unsqueeze(1)
  x_integrated = x_integrated.repeat(1, nb_samples, 1, 1, 1)
  x_integrated = x_integrated * alphas

  y_integrated = y.unsqueeze(1)
  y_integrated = y_integrated.repeat(1, nb_samples)

  igs = None
  for i in range(len(x)):
    ig = x[i] * torch.mean(saliency(model, x_integrated[i], y_integrated[i]), 0, keepdim=True)
    igs = torch.cat([igs, ig], 0) if igs is not None else ig
  
  return igs

explanation_methods = [saliency, input_gradient, smoothgrad, integrad]

# %%
def _tf_to_torch(t):
  t = tf.cast(t, tf.float32).numpy()
  if t.shape[-1] in [1, 3]:
    t = np.moveaxis(t, -1, 1)
  
  t = torch.tensor(t, requires_grad = True).cuda()

  return t

def _torch_to_tf(t):
  try:
    t = t.detach()
  except:
    pass
  try:
    t = t.cpu()
  except:
    pass
  try:
    t = t.numpy()
  except:
    pass
  t = np.array(t)
  if t.shape[1] in [1, 3]:
    t = np.moveaxis(t, 1, -1)
  
  t = np.array(t, np.float32)

  return t

# %%
def find_last_conv_layer(model):
  last_conv = None

  modules_to_look = []
  for module_key in list(model._modules.keys())[::-1]:
    modules_to_look.append((model, module_key, []))

  while len(modules_to_look):
    base_module, module_key, path = modules_to_look.pop(0)
    module = base_module._modules[module_key]

    sub_modules = module._modules
    
    if not len(sub_modules):
      # a layer
      if module.__class__.__name__ == 'Conv2d' and module.out_channels > 1_000:
        print('found', path, module_key)
        return module
    else:
      for next_key in list(module._modules.keys()):
        modules_to_look = [(module, next_key, path + [module_key])] + modules_to_look
  
  # no conv found
  print('[ERROR] not found!')
  return False

# %% [markdown]
# # Only Grad-CAM and Saliency

# %%
# !rm -rf *.csv

# %%
models.list_models("pytorch").index('clip')
# Out:
# 61

# %%
from captum.attr import *

zoo = modelvshuman.models.pytorch.model_zoo
BATCH_SIZE = 16

list_models = models.list_models("pytorch")
#list_models = [ m for m  in list_models if 'bagnet17' not in m and 'bagnet33' not in m and 'resnet50' not in m  ]
for MODEL_NAME in list_models:#models.list_models("pytorch")[60:]:
  print(MODEL_NAME)
  model = getattr(zoo, MODEL_NAME)(MODEL_NAME)
  
  model = model.model.cuda()

  # !rm -rf explanations
  # !mkdir explanations

  RESULTS = []
  img_passed = 0
  ds = get_dataset(BATCH_SIZE, True)
  REDUCERS = [1, 4, 16]

  last_conv = find_last_conv_layer(model)
  gc_explainer = LayerGradCam(model, last_conv)
  ig = IntegratedGradients(model)
  sa_explainer = Saliency(model)
  sg_explainer = NoiseTunnel(sa_explainer)
  oc_explainer = Occlusion(model)

  for x_batch, h_batch, y_batch in ds:

    x_batch = _tf_to_torch(x_batch)
    y_batch = _tf_to_torch(y_batch)
    y_ohe   = torch.argmax(y_batch, axis=-1)

    sa_phi = saliency(model, x_batch, y_batch)
    gi_phi = sa_phi * x_batch
    #ig_phi = ig.attribute(x_batch, target = y_ohe, internal_batch_size = BATCH_SIZE // 2, n_steps = 30)
    #sg_phi = sg_explainer.attribute(x_batch, nt_type='smoothgrad', stdevs=5.0, nt_samples=50, target=y_ohe, nt_samples_batch_size = BATCH_SIZE // 2)
    #oc_phi = oc_explainer.attribute(x_batch, (3, 40, 40), (3, 20, 20), 0.0, target = y_ohe)

    sa_phi = torch.abs(torch.mean(sa_phi, axis=1))
    gi_phi = torch.abs(torch.mean(gi_phi, axis=1))
    #ig_phi = torch.abs(torch.mean(ig_phi, axis=1))
    #sg_phi = torch.abs(torch.mean(sg_phi, axis=1))
    #oc_phi = torch.mean(oc_phi, axis=1)

    gc_phi = gc_explainer.attribute(x_batch, y_ohe)
    gc_phi = _torch_to_tf(gc_phi)
    gc_phi = tf.image.resize(gc_phi, (224, 224)).numpy()

    label = _torch_to_tf(y_batch)
    label = np.argmax(label, -1)

    for phi_name, phi in [
                          ('saliency', sa_phi), 
                          ('gradinput', gi_phi), 
                          ('gradcam', gc_phi), 
                          #('integrad', ig_phi), 
                          #('smoothgrad', sg_phi), 
                          #('occlusion', oc_phi)
                          ]:

      dice_score = dice(_torch_to_tf(phi), h_batch, reducers = REDUCERS)
      spearman_score = spearmanr_sim(_torch_to_tf(phi), h_batch, reducers = REDUCERS)
      iou_score = iou(_torch_to_tf(phi), h_batch, reducers = REDUCERS)

      # saving scores
      for metric_name, scores in [('dice', dice_score), ('spearman', spearman_score), ('iou', iou_score)]:
        for reducer_key in REDUCERS:
          for img_i in range(len(scores[reducer_key])):
            img_id = img_passed + img_i
            RESULTS.append((MODEL_NAME, phi_name, img_id, label[img_i], metric_name, reducer_key, scores[reducer_key][img_i].astype(np.float16)))
      
      # saving explanations
      phi = _torch_to_tf(phi)
      for pid, p in enumerate(phi):
        p -= p.min()
        p /= p.max()
        p *= 255.0

        img_id = pid + img_passed
        cv2.imwrite(f"explanations/{MODEL_NAME}_{phi_name}_{img_id}_{label[pid]}.png",  p.astype(np.uint8))
      
      """
      set_size(10, 4)
      
      for i in range(3):
        plt.subplot(1, 2, 1)
        show(x_batch[i])
        show(phi[i], cmap='jet', p=1, smooth=3.0, alpha=0.35)
        
        plt.subplot(1, 2, 2)
        show(x_batch[i])
        show(h_batch[i], p=False, smooth=False, cmap='jet', alpha=0.35)
        plt.title(phi_name)    
        plt.show()
      """
    img_passed += len(x_batch)
    print(MODEL_NAME, img_passed)

  bucket_name = "serrelab/prj_metapredictor"

  res = pd.DataFrame(RESULTS, columns=[
                                      'model name', 
                                      'attribution name',
                                      'image_id',
                                      'label',
                                      'metric_name',
                                      'reducer',
                                      'metric_score'
  ])
  file_name = f'{MODEL_NAME}_results.csv'
  res.to_csv(file_name)

  # !gsutil cp {file_name} gs://{bucket_name}/
  # !gsutil -m -q cp -r explanations gs://{bucket_name}/ 
  # add quiet mode (-q)

  print('\n\n\n Done for ', MODEL_NAME, '\n\n\n')
# Out:
# bagnet9
# Downloading: "https://bitbucket.org/wielandbrendel/bag-of-feature-pretrained-models/raw/249e8fa82c0913623a807d9d35eeab9da7dcc2a8/bagnet8-34f4ccd2.pth.tar" to /root/.cache/torch/hub/checkpoints/bagnet8-34f4ccd2.pth.tar
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-312e851f2636> in <module>()
#       8 for MODEL_NAME in list_models:#models.list_models("pytorch")[60:]:
#       9   print(MODEL_NAME)
# ---> 10   model = getattr(zoo, MODEL_NAME)(MODEL_NAME)
#      11   model = model.model.cuda()
#      12
#
# /usr/local/lib/python3.7/dist-packages/modelvshuman/models/pytorch/model_zoo.py in bagnet9(model_name, *args)
#      42 def bagnet9(model_name, *args):
#      43     from .bagnets.pytorchnet import bagnet9
# ---> 44     model = bagnet9(pretrained=True)
#      45     model = torch.nn.DataParallel(model)
#      46     return PytorchModel(model, model_name, *args)
#
# /usr/local/lib/python3.7/dist-packages/modelvshuman/models/pytorch/bagnets/pytorchnet.py in bagnet9(pretrained, strides, **kwargs)
#     166     model = BagNet(Bottleneck, [3, 4, 6, 3], strides=strides, kernel3=[1, 1, 0, 0], **kwargs)
#     167     if pretrained:
# --> 168         model.load_state_dict(model_zoo.load_url(model_urls['bagnet9']))
#     169     return model
#
# /usr/local/lib/python3.7/dist-packages/torch/hub.py in load_state_dict_from_url(url, model_dir, map_location, progress, check_hash, file_name)
#     589             r = HASH_REGEX.search(filename)  # r is Optional[Match[str]]
#     590             hash_prefix = r.group(1) if r else None
# --> 591         download_url_to_file(url, cached_file, hash_prefix, progress=progress)
#     592
#     593     if _is_legacy_zip_format(cached_file):
#
# /usr/local/lib/python3.7/dist-packages/torch/hub.py in download_url_to_file(url, dst, hash_prefix, progress)
#     455     file_size = None
#     456     req = Request(url, headers={"User-Agent": "torch.hub"})
# --> 457     u = urlopen(req)
#     458     meta = u.info()
#     459     if hasattr(meta, 'getheaders'):
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /usr/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /usr/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /usr/lib/python3.7/urllib/request.py in https_open(self, req)
#    1391         def https_open(self, req):
#    1392             return self.do_open(http.client.HTTPSConnection, req,
# -> 1393                 context=self._context, check_hostname=self._check_hostname)
#    1394
#    1395         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1351             except OSError as err: # timeout error
#    1352                 raise URLError(err)
# -> 1353             r = h.getresponse()
#    1354         except:
#    1355             h.close()
#
# /usr/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /usr/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
 del model

# %%
clip.available_models()
# Out:
# ['RN50',
#  'RN101',
#  'RN50x4',
#  'RN50x16',
#  'RN50x64',
#  'ViT-B/32',
#  'ViT-B/16',
#  'ViT-L/14',
#  'ViT-L/14@336px']

# %%
from captum.attr import *

zoo = modelvshuman.models.pytorch.model_zoo
BATCH_SIZE = 1
models_clip = [
'ViT-B/16','ViT-B/32',
 'RN50x64',
 'ViT-L/14@336px']
# !rm -rf explanations
# !mkdir explanations 
for MODEL_NAME in models_clip :
  #if 'clipR' not in MODEL_NAME:
  #  continue 
  print(MODEL_NAME)
  #model = getattr(zoo, MODEL_NAME)(MODEL_NAME)
  #zeroshot_weights = model.zeroshot_weights
  model,preprocess = clip.load(MODEL_NAME)
  zeroshot_weights = zeroshot_classifier(imagenet_classes, imagenet_templates,model)
  model = model.cuda()

  

  RESULTS = []
  scores_acc = []
  img_passed = 0
  ds = get_dataset(BATCH_SIZE, True)
  REDUCERS = [1, 4, 16]

  last_conv = find_last_conv_layer(model)
  gc_explainer = LayerGradCam(model, last_conv)
  ig = IntegratedGradients(model)
  sa_explainer = Saliency(model)
  sg_explainer = NoiseTunnel(sa_explainer)
  oc_explainer = Occlusion(model)

  for x_batch, h_batch, y_batch in ds:
    
    x_batch = _tf_to_torch(x_batch)
    x_batch = x_batch-x_batch.min()
    x_batch = x_batch/x_batch.max()
    y_batch = _tf_to_torch(y_batch)
    y_ohe   = torch.argmax(y_batch, axis=-1)
    
    
    #sa_phi = saliency(model, x_batch, y_batch)
    sa_phi = saliency(model, x_batch, y_batch,clip=True,zsw = zeroshot_weights)
    gi_phi = sa_phi * x_batch
    #ig_phi = ig.attribute(x_batch, target = y_ohe, internal_batch_size = BATCH_SIZE // 2, n_steps = 30)
    #sg_phi = sg_explainer.attribute(x_batch, nt_type='smoothgrad', stdevs=5.0, nt_samples=50, target=y_ohe, nt_samples_batch_size = BATCH_SIZE // 2)
    #oc_phi = oc_explainer.attribute(x_batch, (3, 40, 40), (3, 20, 20), 0.0, target = y_ohe)

    sa_phi = torch.abs(torch.mean(sa_phi, axis=1))
    gi_phi = torch.abs(torch.mean(gi_phi, axis=1))
    #ig_phi = torch.abs(torch.mean(ig_phi, axis=1))
    #sg_phi = torch.abs(torch.mean(sg_phi, axis=1))
    #oc_phi = torch.mean(oc_phi, axis=1)

    #gc_phi = gc_explainer.attribute(x_batch, y_ohe)
    #gc_phi = _torch_to_tf(gc_phi)
    #gc_phi = tf.image.resize(gc_phi, (224, 224)).numpy()

    label = _torch_to_tf(y_batch)
    label = np.argmax(label, -1)

    # Checking accuracy
    image_features = model.encode_image(x_batch)
    image_features = image_features/image_features.norm(dim=-1, keepdim=True)
    y_pred = 100.*image_features@zeroshot_weights
    #y_pred = model.forward_batch(x_batch)

    s = torch.argmax(y_pred, -1) == y_ohe
    for _s in s:
      scores_acc.append(_s.cpu().numpy())
    print('mean score of the model:',np.mean(scores_acc))

    for phi_name, phi in [
                          ('saliency', sa_phi), 
                          ('gradinput', gi_phi), 
                          #('gradcam', gc_phi), 
                          #('integrad', ig_phi), 
                          #('smoothgrad', sg_phi), 
                          #('occlusion', oc_phi)
                          ]:

      dice_score = dice(_torch_to_tf(phi), h_batch, reducers = REDUCERS)
      spearman_score = spearmanr_sim(_torch_to_tf(phi), h_batch, reducers = REDUCERS)
      iou_score = iou(_torch_to_tf(phi), h_batch, reducers = REDUCERS)

      # saving scores
      for metric_name, scores in [('dice', dice_score), ('spearman', spearman_score), ('iou', iou_score)]:
        for reducer_key in REDUCERS:
          for img_i in range(len(scores[reducer_key])):
            img_id = img_passed + img_i
            RESULTS.append((MODEL_NAME, phi_name, img_id, label[img_i], metric_name, reducer_key, scores[reducer_key][img_i]))
      
      # saving explanations
      phi = _torch_to_tf(phi)
      for pid, p in enumerate(phi):
        p -= p.min()
        p /= p.max()
        p *= 255.0

        img_id = pid + img_passed
        cv2.imwrite(f"explanations/{MODEL_NAME}_{phi_name}_{img_id}_{label[pid]}.png",  p.astype(np.uint8))
      
      """
      set_size(10, 4)
      
      for i in range(3):
        plt.subplot(1, 2, 1)
        show(x_batch[i])
        show(phi[i], cmap='jet', p=1, smooth=3.0, alpha=0.35)
        
        plt.subplot(1, 2, 2)
        show(x_batch[i])
        show(h_batch[i], p=False, smooth=False, cmap='jet', alpha=0.35)
        plt.title(phi_name)    
        plt.show()
      """
    img_passed += len(x_batch)
    print(MODEL_NAME, img_passed)

  bucket_name = "serrelab/prj_metapredictor"

  res = pd.DataFrame(RESULTS, columns=[
                                      'model name', 
                                      'attribution name',
                                      'image_id',
                                      'label',
                                      'metric_name',
                                      'reducer',
                                      'metric_score'
  ])
  file_name = f'{MODEL_NAME}_results.csv'
  res.to_csv(file_name)

  # !gsutil cp {file_name} gs://{bucket_name}/

  # add quiet mode (-q)

  print('\n\n\n Done for ', MODEL_NAME, '\n\n\n')
# !gsutil -m -q cp -r explanations gs://{bucket_name}/
# Out:
# ViT-B/16
# 100%|███████████████████████████████████████| 335M/335M [00:04<00:00, 87.6MiB/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# mean score of the model: 0.649672131147541
# ViT-B/16 6100
# mean score of the model: 0.6497295525323717
# ViT-B/16 6101
# mean score of the model: 0.6497869550966896
# ViT-B/16 6102
# mean score of the model: 0.649844338849746
# ViT-B/16 6103
# mean score of the model: 0.6497378768020969
# ViT-B/16 6104
# mean score of the model: 0.6497952497952498
# ViT-B/16 6105
# mean score of the model: 0.6498526039960695
# ViT-B/16 6106
# mean score of the model: 0.6499099394137875
# ViT-B/16 6107
# mean score of the model: 0.6499672560576293
# ViT-B/16 6108
# mean score of the model: 0.6498608610247176
# ViT-B/16 6109
# mean score of the model: 0.6497545008183306
# ViT-B/16 6110
# mean score of the model: 0.6496481754213713
# ViT-B/16 6111
# mean score of the model: 0.649705497382199
# ViT-B/16 6112
# mean score of the model: 0.6497628005889089
# ViT-B/16 6113
# mean score of the model: 0.6498200850507033
# ViT-B/16 6114
# mean score of the model: 0.6498773507767784
# ViT-B/16 6115
# mean score of the model: 0.6497710922171354
# ViT-B/16 6116
# mean score of the model: 0.6496648683995423
# ViT-B/16 6117
# mean score of the model: 0.6497221314154953
# ViT-B/16 6118
# mean score of the model: 0.6497793757149861
# ViT-B/16 6119
# mean score of the model: 0.6498366013071896
# ViT-B/16 6120
# mean score of the model: 0.6497304362032348
# ViT-B/16 6121
# mean score of the model: 0.649624305782424
# ViT-B/16 6122
# mean score of the model: 0.6495182100277642
# ViT-B/16 6123
# mean score of the model: 0.6494121489222731
# ViT-B/16 6124
# mean score of the model: 0.6493061224489796
# ViT-B/16 6125
# mean score of the model: 0.649200130590924
# ViT-B/16 6126
# mean score of the model: 0.6490941733311572
# ViT-B/16 6127
# mean score of the model: 0.6489882506527415
# ViT-B/16 6128
# mean score of the model: 0.6490455212922174
# ViT-B/16 6129
# mean score of the model: 0.6491027732463295
# ViT-B/16 6130
# mean score of the model: 0.6491600065242211
# ViT-B/16 6131
# mean score of the model: 0.6492172211350293
# ViT-B/16 6132
# mean score of the model: 0.6492744170878852
# ViT-B/16 6133
# mean score of the model: 0.6493315943919139
# ViT-B/16 6134
# mean score of the model: 0.6493887530562347
# ViT-B/16 6135
# mean score of the model: 0.6492829204693612
# ViT-B/16 6136
# mean score of the model: 0.6491771223724947
# ViT-B/16 6137
# mean score of the model: 0.6490713587487781
# ViT-B/16 6138
# mean score of the model: 0.648965629581365
# ViT-B/16 6139
# mean score of the model: 0.6490228013029316
# ViT-B/16 6140
# mean score of the model: 0.6489171144764696
# ViT-B/16 6141
# mean score of the model: 0.6489742754802996
# ViT-B/16 6142
# mean score of the model: 0.649031417874003
# ViT-B/16 6143
# mean score of the model: 0.6490885416666666
# ViT-B/16 6144
# mean score of the model: 0.6491456468673719
# ViT-B/16 6145
# mean score of the model: 0.6490400260331923
# ViT-B/16 6146
# mean score of the model: 0.6490971205466081
# ViT-B/16 6147
# mean score of the model: 0.6491541964866623
# ViT-B/16 6148
# mean score of the model: 0.6492112538624166
# ViT-B/16 6149
# mean score of the model: 0.6492682926829269
# ViT-B/16 6150
# mean score of the model: 0.6493253129572427
# ViT-B/16 6151
# mean score of the model: 0.6493823146944083
# ViT-B/16 6152
# mean score of the model: 0.6494392979034618
# ViT-B/16 6153
# mean score of the model: 0.6493337666558336
# ViT-B/16 6154
# mean score of the model: 0.6493907392363931
# ViT-B/16 6155
# mean score of the model: 0.6494476933073424
# ViT-B/16 6156
# mean score of the model: 0.6493422121162904
# ViT-B/16 6157
# mean score of the model: 0.6493991555699903
# ViT-B/16 6158
# mean score of the model: 0.649456080532554
# ViT-B/16 6159
# mean score of the model: 0.649512987012987
# ViT-B/16 6160
# mean score of the model: 0.649569875020289
# ViT-B/16 6161
# mean score of the model: 0.6494644595910418
# ViT-B/16 6162
# mean score of the model: 0.6493590783709232
# ViT-B/16 6163
# mean score of the model: 0.649415963659961
# ViT-B/16 6164
# mean score of the model: 0.6493106244931063
# ViT-B/16 6165
# mean score of the model: 0.6493674991891015
# ViT-B/16 6166
# mean score of the model: 0.6494243554402465
# ViT-B/16 6167
# mean score of the model: 0.64931906614786
# ViT-B/16 6168
# mean score of the model: 0.6492138109904361
# ViT-B/16 6169
# mean score of the model: 0.6491085899513777
# ViT-B/16 6170
# mean score of the model: 0.6490034030140982
# ViT-B/16 6171
# mean score of the model: 0.6490602721970188
# ViT-B/16 6172
# mean score of the model: 0.6491171229548032
# ViT-B/16 6173
# mean score of the model: 0.6490119857466796
# ViT-B/16 6174
# mean score of the model: 0.6489068825910931
# ViT-B/16 6175
# mean score of the model: 0.6489637305699482
# ViT-B/16 6176
# mean score of the model: 0.649020560142464
# ViT-B/16 6177
# mean score of the model: 0.6490773713175785
# ViT-B/16 6178
# mean score of the model: 0.649134164104224
# ViT-B/16 6179
# mean score of the model: 0.6491909385113268
# ViT-B/16 6180
# mean score of the model: 0.6492476945478078
# ViT-B/16 6181
# mean score of the model: 0.6491426722743449
# ViT-B/16 6182
# mean score of the model: 0.6491994177583698
# ViT-B/16 6183
# mean score of the model: 0.6492561448900388
# ViT-B/16 6184
# mean score of the model: 0.6493128536782539
# ViT-B/16 6185
# mean score of the model: 0.6492078887811187
# ViT-B/16 6186
# mean score of the model: 0.6492645870373364
# ViT-B/16 6187
# mean score of the model: 0.6491596638655462
# ViT-B/16 6188
# mean score of the model: 0.6492163515915333
# ViT-B/16 6189
# mean score of the model: 0.6492730210016155
# ViT-B/16 6190
# mean score of the model: 0.6493296721046681
# ViT-B/16 6191
# mean score of the model: 0.6493863049095607
# ViT-B/16 6192
# mean score of the model: 0.6494429194251574
# ViT-B/16 6193
# mean score of the model: 0.6494995156603164
# ViT-B/16 6194
# mean score of the model: 0.6495560936238902
# ViT-B/16 6195
# mean score of the model: 0.6496126533247256
# ViT-B/16 6196
# mean score of the model: 0.6496691947716637
# ViT-B/16 6197
# mean score of the model: 0.6497257179735398
# ViT-B/16 6198
# mean score of the model: 0.6496209065978383
# ViT-B/16 6199
# mean score of the model: 0.6496774193548387
# ViT-B/16 6200
# mean score of the model: 0.6497339138848572
# ViT-B/16 6201
# mean score of the model: 0.6497903901967107
# ViT-B/16 6202
# mean score of the model: 0.6496856359825891
# ViT-B/16 6203
# mean score of the model: 0.6497421018697614
# ViT-B/16 6204
# mean score of the model: 0.649798549556809
# ViT-B/16 6205
# mean score of the model: 0.6498549790525298
# ViT-B/16 6206
# mean score of the model: 0.6499113903657161
# ViT-B/16 6207
# mean score of the model: 0.6498067010309279
# ViT-B/16 6208
# mean score of the model: 0.649863101948784
# ViT-B/16 6209
# mean score of the model: 0.6499194847020934
# ViT-B/16 6210
# mean score of the model: 0.6499758492996297
# ViT-B/16 6211
# mean score of the model: 0.650032195750161
# ViT-B/16 6212
# mean score of the model: 0.649927571221632
# ViT-B/16 6213
# mean score of the model: 0.6498229803669134
# ViT-B/16 6214
# mean score of the model: 0.6498793242156075
# ViT-B/16 6215
# mean score of the model: 0.6497747747747747
# ViT-B/16 6216
# mean score of the model: 0.6498311082515683
# ViT-B/16 6217
# mean score of the model: 0.6498874236088774
# ViT-B/16 6218
# mean score of the model: 0.649943720855443
# ViT-B/16 6219
# mean score of the model: 0.65
# ViT-B/16 6220
# mean score of the model: 0.6498955151904838
# ViT-B/16 6221
# mean score of the model: 0.6499517839922855
# ViT-B/16 6222
# mean score of the model: 0.650008034709947
# ViT-B/16 6223
# mean score of the model: 0.6500642673521851
# ViT-B/16 6224
# mean score of the model: 0.6499598393574297
# ViT-B/16 6225
# mean score of the model: 0.650016061676839
# ViT-B/16 6226
# mean score of the model: 0.649911674963867
# ViT-B/16 6227
# mean score of the model: 0.6499678869621066
# ViT-B/16 6228
# mean score of the model: 0.6500240809118638
# ViT-B/16 6229
# mean score of the model: 0.6500802568218299
# ViT-B/16 6230
# mean score of the model: 0.6499759268175253
# ViT-B/16 6231
# mean score of the model: 0.6500320924261874
# ViT-B/16 6232
# mean score of the model: 0.6499278036258623
# ViT-B/16 6233
# mean score of the model: 0.6499839589348733
# ViT-B/16 6234
# mean score of the model: 0.6498797113071372
# ViT-B/16 6235
# mean score of the model: 0.6499358563181526
# ViT-B/16 6236
# mean score of the model: 0.6499919833253167
# ViT-B/16 6237
# mean score of the model: 0.649887784546329
# ViT-B/16 6238
# mean score of the model: 0.6499439012662286
# ViT-B/16 6239
# mean score of the model: 0.65
# ViT-B/16 6240
# mean score of the model: 0.6500560807562891
# ViT-B/16 6241
# mean score of the model: 0.650112143543736
# ViT-B/16 6242
# mean score of the model: 0.6501681883709755
# ViT-B/16 6243
# mean score of the model: 0.6502242152466368
# ViT-B/16 6244
# mean score of the model: 0.6502802241793435
# ViT-B/16 6245
# mean score of the model: 0.6503362151777138
# ViT-B/16 6246
# mean score of the model: 0.6502321114134785
# ViT-B/16 6247
# mean score of the model: 0.6502880921895007
# ViT-B/16 6248
# mean score of the model: 0.6501840294447112
# ViT-B/16 6249
# mean score of the model: 0.65024
# ViT-B/16 6250
# mean score of the model: 0.6502959526475763
# ViT-B/16 6251
# mean score of the model: 0.6501919385796545
# ViT-B/16 6252
# mean score of the model: 0.6500879577802655
# ViT-B/16 6253
# mean score of the model: 0.6501439078989447
# ViT-B/16 6254
# mean score of the model: 0.6500399680255795
# ViT-B/16 6255
# mean score of the model: 0.6499360613810742
# ViT-B/16 6256
# mean score of the model: 0.6498321879494966
# ViT-B/16 6257
# mean score of the model: 0.6498881431767338
# ViT-B/16 6258
# mean score of the model: 0.6499440805240454
# ViT-B/16 6259
# mean score of the model: 0.65
# ViT-B/16 6260
# mean score of the model: 0.6500559016131608
# ViT-B/16 6261
# mean score of the model: 0.6501117853720856
# ViT-B/16 6262
# mean score of the model: 0.6501676512853265
# ViT-B/16 6263
# mean score of the model: 0.6502234993614304
# ViT-B/16 6264
# mean score of the model: 0.650119712689545
# ViT-B/16 6265
# mean score of the model: 0.6501755505904884
# ViT-B/16 6266
# mean score of the model: 0.6502313706717727
# ViT-B/16 6267
# mean score of the model: 0.6502871729419273
# ViT-B/16 6268
# mean score of the model: 0.6503429574094752
# ViT-B/16 6269
# mean score of the model: 0.6503987240829346
# ViT-B/16 6270
# mean score of the model: 0.650295008770531
# ViT-B/16 6271
# mean score of the model: 0.6503507653061225
# ViT-B/16 6272
# mean score of the model: 0.6504065040650406
# ViT-B/16 6273
# mean score of the model: 0.6504622250557858
# ViT-B/16 6274
# mean score of the model: 0.6503585657370518
# ViT-B/16 6275
# mean score of the model: 0.6504142766093053
# ViT-B/16 6276
# mean score of the model: 0.6503106579576231
# ViT-B/16 6277
# mean score of the model: 0.6502070723160243
# ViT-B/16 6278
# mean score of the model: 0.6502627806975633
# ViT-B/16 6279
# mean score of the model: 0.6503184713375796
# ViT-B/16 6280
# mean score of the model: 0.6502149339277186
# ViT-B/16 6281
# mean score of the model: 0.6502706144539956
# ViT-B/16 6282
# mean score of the model: 0.6503262772560878
# ViT-B/16 6283
# mean score of the model: 0.6503819223424571
# ViT-B/16 6284
# mean score of the model: 0.6504375497215593
# ViT-B/16 6285
# mean score of the model: 0.6504931594018454
# ViT-B/16 6286
# mean score of the model: 0.6503896930173374
# ViT-B/16 6287
# mean score of the model: 0.6504452926208651
# ViT-B/16 6288
# mean score of the model: 0.6505008745428525
# ViT-B/16 6289
# mean score of the model: 0.6505564387917329
# ViT-B/16 6290
# mean score of the model: 0.6504530281354316
# ViT-B/16 6291
# mean score of the model: 0.6505085823267641
# ViT-B/16 6292
# mean score of the model: 0.6505641188622279
# ViT-B/16 6293
# mean score of the model: 0.6506196377502383
# ViT-B/16 6294
# mean score of the model: 0.6505162827640985
# ViT-B/16 6295
# mean score of the model: 0.650412960609911
# ViT-B/16 6296
# mean score of the model: 0.6504684770525647
# ViT-B/16 6297
# mean score of the model: 0.650523975865354
# ViT-B/16 6298
# mean score of the model: 0.6504207016986824
# ViT-B/16 6299
# mean score of the model: 0.6504761904761904
# ViT-B/16 6300
# mean score of the model: 0.6505316616410094
# ViT-B/16 6301
# mean score of the model: 0.6505871152015233
# ViT-B/16 6302
# mean score of the model: 0.650483896557195
# ViT-B/16 6303
# mean score of the model: 0.6505393401015228
# ViT-B/16 6304
# mean score of the model: 0.6505947660586836
# ViT-B/16 6305
# mean score of the model: 0.6506501744370441
# ViT-B/16 6306
# mean score of the model: 0.6507055652449659
# ViT-B/16 6307
# mean score of the model: 0.6506024096385542
# ViT-B/16 6308
# mean score of the model: 0.6506577904580758
# ViT-B/16 6309
# mean score of the model: 0.6507131537242472
# ViT-B/16 6310
# mean score of the model: 0.6506100459515133
# ViT-B/16 6311
# mean score of the model: 0.6506653992395437
# ViT-B/16 6312
# mean score of the model: 0.6505623316964992
# ViT-B/16 6313
# mean score of the model: 0.6504592968007602
# ViT-B/16 6314
# mean score of the model: 0.6505146476642913
# ViT-B/16 6315
# mean score of the model: 0.6504116529449019
# ViT-B/16 6316
# mean score of the model: 0.6504669938261833
# ViT-B/16 6317
# mean score of the model: 0.6503640392529282
# ViT-B/16 6318
# mean score of the model: 0.65026111726539
# ViT-B/16 6319
# mean score of the model: 0.6503164556962026
# ViT-B/16 6320
# mean score of the model: 0.6503717766176238
# ViT-B/16 6321
# mean score of the model: 0.6502689022461247
# ViT-B/16 6322
# mean score of the model: 0.6503242131899415
# ViT-B/16 6323
# mean score of the model: 0.6503795066413662
# ViT-B/16 6324
# mean score of the model: 0.6502766798418972
# ViT-B/16 6325
# mean score of the model: 0.6503319633259563
# ViT-B/16 6326
# mean score of the model: 0.6503872293345978
# ViT-B/16 6327
# mean score of the model: 0.6504424778761062
# ViT-B/16 6328
# mean score of the model: 0.6504977089587612
# ViT-B/16 6329
# mean score of the model: 0.650394944707741
# ViT-B/16 6330
# mean score of the model: 0.6504501658505766
# ViT-B/16 6331
# mean score of the model: 0.6503474415666456
# ViT-B/16 6332
# mean score of the model: 0.6504026527711985
# ViT-B/16 6333
# mean score of the model: 0.6502999684243764
# ViT-B/16 6334
# mean score of the model: 0.6503551696921863
# ViT-B/16 6335
# mean score of the model: 0.6504103535353535
# ViT-B/16 6336
# mean score of the model: 0.650307716585135
# ViT-B/16 6337
# mean score of the model: 0.6502051120227201
# ViT-B/16 6338
# mean score of the model: 0.6502602934216754
# ViT-B/16 6339
# mean score of the model: 0.6503154574132493
# ViT-B/16 6340
# mean score of the model: 0.6503706040056774
# ViT-B/16 6341
# mean score of the model: 0.6504257332071902
# ViT-B/16 6342
# mean score of the model: 0.6504808450260129
# ViT-B/16 6343
# mean score of the model: 0.6503783102143758
# ViT-B/16 6344
# mean score of the model: 0.6502758077226163
# ViT-B/16 6345
# mean score of the model: 0.6503309171131422
# ViT-B/16 6346
# mean score of the model: 0.6502284543878998
# ViT-B/16 6347
# mean score of the model: 0.6502835538752363
# ViT-B/16 6348
# mean score of the model: 0.6501811308867538
# ViT-B/16 6349
# mean score of the model: 0.6500787401574804
# ViT-B/16 6350
# mean score of the model: 0.6501338371909935
# ViT-B/16 6351
# mean score of the model: 0.6500314861460957
# ViT-B/16 6352
# mean score of the model: 0.6500865732724697
# ViT-B/16 6353
# mean score of the model: 0.6499842618822789
# ViT-B/16 6354
# mean score of the model: 0.6498819826907947
# ViT-B/16 6355
# mean score of the model: 0.6499370673379484
# ViT-B/16 6356
# mean score of the model: 0.6498348277489382
# ViT-B/16 6357
# mean score of the model: 0.6498899024850582
# ViT-B/16 6358
# mean score of the model: 0.6499449598993552
# ViT-B/16 6359
# mean score of the model: 0.65
# ViT-B/16 6360
# mean score of the model: 0.6498978148089923
# ViT-B/16 6361
# mean score of the model: 0.6499528450172901
# ViT-B/16 6362
# mean score of the model: 0.65000785792865
# ViT-B/16 6363
# mean score of the model: 0.6499057196731616
# ViT-B/16 6364
# mean score of the model: 0.6499607227022781
# ViT-B/16 6365
# mean score of the model: 0.6498586239396795
# ViT-B/16 6366
# mean score of the model: 0.6499136170881106
# ViT-B/16 6367
# mean score of the model: 0.6499685929648241
# ViT-B/16 6368
# mean score of the model: 0.6500235515779558
# ViT-B/16 6369
# mean score of the model: 0.6499215070643642
# ViT-B/16 6370
# mean score of the model: 0.6498194945848376
# ViT-B/16 6371
# mean score of the model: 0.6497175141242938
# ViT-B/16 6372
# mean score of the model: 0.649772477640044
# ViT-B/16 6373
# mean score of the model: 0.6496705365547537
# ViT-B/16 6374
# mean score of the model: 0.6495686274509804
# ViT-B/16 6375
# mean score of the model: 0.6496235884567126
# ViT-B/16 6376
# mean score of the model: 0.6496785322251842
# ViT-B/16 6377
# mean score of the model: 0.649733458764503
# ViT-B/16 6378
# mean score of the model: 0.6496316036996395
# ViT-B/16 6379
# mean score of the model: 0.6496865203761756
# ViT-B/16 6380
# mean score of the model: 0.6497414198401504
# ViT-B/16 6381
# mean score of the model: 0.6496396114070824
# ViT-B/16 6382
# mean score of the model: 0.6496945010183299
# ViT-B/16 6383
# mean score of the model: 0.649749373433584
# ViT-B/16 6384
# mean score of the model: 0.6496476115896632
# ViT-B/16 6385
# mean score of the model: 0.6497024741622299
# ViT-B/16 6386
# mean score of the model: 0.6496007515265383
# ViT-B/16 6387
# mean score of the model: 0.6496556042579837
# ViT-B/16 6388
# mean score of the model: 0.6497104398184379
# ViT-B/16 6389
# mean score of the model: 0.6497652582159624
# ViT-B/16 6390
# mean score of the model: 0.6496635894226256
# ViT-B/16 6391
# mean score of the model: 0.6495619524405507
# ViT-B/16 6392
# mean score of the model: 0.6496167683403723
# ViT-B/16 6393
# mean score of the model: 0.6496715670941507
# ViT-B/16 6394
# mean score of the model: 0.6497263487099296
# ViT-B/16 6395
# mean score of the model: 0.6497811131957474
# ViT-B/16 6396
# mean score of the model: 0.6496795372831015
# ViT-B/16 6397
# mean score of the model: 0.6495779931228509
# ViT-B/16 6398
# mean score of the model: 0.6496327551179872
# ViT-B/16 6399
# mean score of the model: 0.6496875
# ViT-B/16 6400
# mean score of the model: 0.6495860021871582
# ViT-B/16 6401
# mean score of the model: 0.6496407372696033
# ViT-B/16 6402
# mean score of the model: 0.6495392784632203
# ViT-B/16 6403
# mean score of the model: 0.6495940037476577
# ViT-B/16 6404
# mean score of the model: 0.6496487119437939
# ViT-B/16 6405
# mean score of the model: 0.6495472994068061
# ViT-B/16 6406
# mean score of the model: 0.6496019978148899
# ViT-B/16 6407
# mean score of the model: 0.6495006242197253
# ViT-B/16 6408
# mean score of the model: 0.6493992822593229
# ViT-B/16 6409
# mean score of the model: 0.6494539781591263
# ViT-B/16 6410
# mean score of the model: 0.6495086569957885
# ViT-B/16 6411
# mean score of the model: 0.6495633187772926
# ViT-B/16 6412
# mean score of the model: 0.649617963511617
# ViT-B/16 6413
# mean score of the model: 0.6495166822575615
# ViT-B/16 6414
# mean score of the model: 0.6495713172252533
# ViT-B/16 6415
# mean score of the model: 0.6494700748129676
# ViT-B/16 6416
# mean score of the model: 0.6495247000155836
# ViT-B/16 6417
# mean score of the model: 0.6495793081956996
# ViT-B/16 6418
# mean score of the model: 0.6496338993612712
# ViT-B/16 6419
# mean score of the model: 0.6496884735202493
# ViT-B/16 6420
# mean score of the model: 0.6495872916991123
# ViT-B/16 6421
# mean score of the model: 0.6494861413889754
# ViT-B/16 6422
# mean score of the model: 0.6495407130624319
# ViT-B/16 6423
# mean score of the model: 0.6495952677459527
# ViT-B/16 6424
# mean score of the model: 0.6494941634241245
# ViT-B/16 6425
# mean score of the model: 0.6495487083722378
# ViT-B/16 6426
# mean score of the model: 0.6494476427571184
# ViT-B/16 6427
# mean score of the model: 0.64934660858743
# ViT-B/16 6428
# mean score of the model: 0.649245605848499
# ViT-B/16 6429
# mean score of the model: 0.649144634525661
# ViT-B/16 6430
# mean score of the model: 0.649199191416576
# ViT-B/16 6431
# mean score of the model: 0.6492537313432836
# ViT-B/16 6432
# mean score of the model: 0.649308254313695
# ViT-B/16 6433
# mean score of the model: 0.6493627603357165
# ViT-B/16 6434
# mean score of the model: 0.6494172494172494
# ViT-B/16 6435
# mean score of the model: 0.6494717215661902
# ViT-B/16 6436
# mean score of the model: 0.6495261767904303
# ViT-B/16 6437
# mean score of the model: 0.6495806150978565
# ViT-B/16 6438
# mean score of the model: 0.6496350364963503
# ViT-B/16 6439
# mean score of the model: 0.6496894409937888
# ViT-B/16 6440
# mean score of the model: 0.6497438285980438
# ViT-B/16 6441
# mean score of the model: 0.6497981993169824
# ViT-B/16 6442
# mean score of the model: 0.6496973459568524
# ViT-B/16 6443
# mean score of the model: 0.6497517070142769
# ViT-B/16 6444
# mean score of the model: 0.6498060512024826
# ViT-B/16 6445
# mean score of the model: 0.6498603785293205
# ViT-B/16 6446
# mean score of the model: 0.6499146890026369
# ViT-B/16 6447
# mean score of the model: 0.6498138957816377
# ViT-B/16 6448
# mean score of the model: 0.6498681966196309
# ViT-B/16 6449
# mean score of the model: 0.649922480620155
# ViT-B/16 6450
# mean score of the model: 0.6499767477910402
# ViT-B/16 6451
# mean score of the model: 0.6500309981401116
# ViT-B/16 6452
# mean score of the model: 0.6500852316751898
# ViT-B/16 6453
# mean score of the model: 0.6501394484040904
# ViT-B/16 6454
# mean score of the model: 0.6500387296669249
# ViT-B/16 6455
# mean score of the model: 0.650092936802974
# ViT-B/16 6456
# mean score of the model: 0.6501471271488307
# ViT-B/16 6457
# mean score of the model: 0.6500464540105296
# ViT-B/16 6458
# mean score of the model: 0.6501006347731847
# ViT-B/16 6459
# mean score of the model: 0.6501547987616099
# ViT-B/16 6460
# mean score of the model: 0.6502089459835939
# ViT-B/16 6461
# mean score of the model: 0.6502630764469205
# ViT-B/16 6462
# mean score of the model: 0.6503171901593687
# ViT-B/16 6463
# mean score of the model: 0.6503712871287128
# ViT-B/16 6464
# mean score of the model: 0.6504253673627224
# ViT-B/16 6465
# mean score of the model: 0.6503247757500773
# ViT-B/16 6466
# mean score of the model: 0.6502242152466368
# ViT-B/16 6467
# mean score of the model: 0.6501236858379715
# ViT-B/16 6468
# mean score of the model: 0.6501777709074046
# ViT-B/16 6469
# mean score of the model: 0.6502318392581143
# ViT-B/16 6470
# mean score of the model: 0.6502858908978519
# ViT-B/16 6471
# mean score of the model: 0.6501854140914709
# ViT-B/16 6472
# mean score of the model: 0.6502394562026881
# ViT-B/16 6473
# mean score of the model: 0.6502934816187829
# ViT-B/16 6474
# mean score of the model: 0.6501930501930502
# ViT-B/16 6475
# mean score of the model: 0.6502470660901791
# ViT-B/16 6476
# mean score of the model: 0.6501466728423653
# ViT-B/16 6477
# mean score of the model: 0.6502006792219821
# ViT-B/16 6478
# mean score of the model: 0.6501003241240932
# ViT-B/16 6479
# mean score of the model: 0.65
# ViT-B/16 6480
# mean score of the model: 0.6500540040117266
# ViT-B/16 6481
# mean score of the model: 0.6501079913606912
# ViT-B/16 6482
# mean score of the model: 0.6500077124787906
# ViT-B/16 6483
# mean score of the model: 0.6499074645280691
# ViT-B/16 6484
# mean score of the model: 0.6499614494988435
# ViT-B/16 6485
# mean score of the model: 0.6500154178230034
# ViT-B/16 6486
# mean score of the model: 0.6499152150454756
# ViT-B/16 6487
# mean score of the model: 0.6499691738594328
# ViT-B/16 6488
# mean score of the model: 0.6500231160425335
# ViT-B/16 6489
# mean score of the model: 0.6499229583975347
# ViT-B/16 6490
# mean score of the model: 0.6499768910799568
# ViT-B/16 6491
# mean score of the model: 0.6498767714109673
# ViT-B/16 6492
# mean score of the model: 0.6499306945941783
# ViT-B/16 6493
# mean score of the model: 0.6499846011703111
# ViT-B/16 6494
# mean score of the model: 0.6498845265588915
# ViT-B/16 6495
# mean score of the model: 0.6497844827586207
# ViT-B/16 6496
# mean score of the model: 0.6496844697552716
# ViT-B/16 6497
# mean score of the model: 0.6497383810403201
# ViT-B/16 6498
# mean score of the model: 0.6496384059086013
# ViT-B/16 6499
# mean score of the model: 0.6496923076923077
# ViT-B/16 6500
# mean score of the model: 0.649746192893401
# ViT-B/16 6501
# mean score of the model: 0.6496462626884035
# ViT-B/16 6502
# mean score of the model: 0.6497001383976626
# ViT-B/16 6503
# mean score of the model: 0.6497539975399754
# ViT-B/16 6504
# mean score of the model: 0.6496541122213682
# ViT-B/16 6505
# mean score of the model: 0.6497079618813403
# ViT-B/16 6506
# mean score of the model: 0.6496081143384048
# ViT-B/16 6507
# mean score of the model: 0.6495082974800246
# ViT-B/16 6508
# mean score of the model: 0.6495621447226917
# ViT-B/16 6509
# mean score of the model: 0.6494623655913978
# ViT-B/16 6510
# mean score of the model: 0.6493626171095069
# ViT-B/16 6511
# mean score of the model: 0.649416461916462
# ViT-B/16 6512
# mean score of the model: 0.6493167511131583
# ViT-B/16 6513
# mean score of the model: 0.6493705864292294
# ViT-B/16 6514
# mean score of the model: 0.649424405218726
# ViT-B/16 6515
# mean score of the model: 0.6494782074892572
# ViT-B/16 6516
# mean score of the model: 0.6495319932484271
# ViT-B/16 6517
# mean score of the model: 0.6495857625038355
# ViT-B/16 6518
# mean score of the model: 0.6496395152630772
# ViT-B/16 6519
# mean score of the model: 0.6496932515337424
# ViT-B/16 6520
# mean score of the model: 0.6497469713234166
# ViT-B/16 6521
# mean score of the model: 0.6496473474394358
# ViT-B/16 6522
# mean score of the model: 0.6495477541008738
# ViT-B/16 6523
# mean score of the model: 0.6496014714898835
# ViT-B/16 6524
# mean score of the model: 0.6495019157088122
# ViT-B/16 6525
# mean score of the model: 0.6495556236592093
# ViT-B/16 6526
# mean score of the model: 0.6496093151524437
# ViT-B/16 6527
# mean score of the model: 0.6496629901960784
# ViT-B/16 6528
# mean score of the model: 0.6497166487976719
# ViT-B/16 6529
# mean score of the model: 0.6497702909647779
# ViT-B/16 6530
# mean score of the model: 0.6498239167049457
# ViT-B/16 6531
# mean score of the model: 0.6498775260257196
# ViT-B/16 6532
# mean score of the model: 0.6499311189346395
# ViT-B/16 6533
# mean score of the model: 0.6498316498316499
# ViT-B/16 6534
# mean score of the model: 0.6498852333588371
# ViT-B/16 6535
# mean score of the model: 0.6499388004895961
# ViT-B/16 6536
# mean score of the model: 0.6499923512314517
# ViT-B/16 6537
# mean score of the model: 0.6500458855919241
# ViT-B/16 6538
# mean score of the model: 0.6500994035785288
# ViT-B/16 6539
# mean score of the model: 0.6501529051987768
# ViT-B/16 6540
# mean score of the model: 0.650053508637823
# ViT-B/16 6541
# mean score of the model: 0.6501070009171507
# ViT-B/16 6542
# mean score of the model: 0.6501604768454837
# ViT-B/16 6543
# mean score of the model: 0.6500611246943765
# ViT-B/16 6544
# mean score of the model: 0.6499618029029793
# ViT-B/16 6545
# mean score of the model: 0.6500152765047357
# ViT-B/16 6546
# mean score of the model: 0.6500687337711929
# ViT-B/16 6547
# mean score of the model: 0.650122174709835
# ViT-B/16 6548
# mean score of the model: 0.6500229042601924
# ViT-B/16 6549
# mean score of the model: 0.6500763358778626
# ViT-B/16 6550
# mean score of the model: 0.6501297511830255
# ViT-B/16 6551
# mean score of the model: 0.6501831501831502
# ViT-B/16 6552
# mean score of the model: 0.6502365328857012
# ViT-B/16 6553
# mean score of the model: 0.6501373207201709
# ViT-B/16 6554
# mean score of the model: 0.6501906941266209
# ViT-B/16 6555
# mean score of the model: 0.6502440512507627
# ViT-B/16 6556
# mean score of the model: 0.6502973921000458
# ViT-B/16 6557
# mean score of the model: 0.650198231168039
# ViT-B/16 6558
# mean score of the model: 0.650099100472633
# ViT-B/16 6559
# mean score of the model: 0.65
# ViT-B/16 6560
# mean score of the model: 0.6500533455265965
# ViT-B/16 6561
# mean score of the model: 0.6501066747942701
# ViT-B/16 6562
# mean score of the model: 0.6500076184671644
# ViT-B/16 6563
# mean score of the model: 0.6500609384521633
# ViT-B/16 6564
# mean score of the model: 0.6499619192688499
# ViT-B/16 6565
# mean score of the model: 0.6500152299725861
# ViT-B/16 6566
# mean score of the model: 0.6500685244403838
# ViT-B/16 6567
# mean score of the model: 0.6501218026796589
# ViT-B/16 6568
# mean score of the model: 0.6501750646978232
# ViT-B/16 6569
# mean score of the model: 0.6500761035007611
# ViT-B/16 6570
# mean score of the model: 0.6501293562623649
# ViT-B/16 6571
# mean score of the model: 0.6500304321363359
# ViT-B/16 6572
# mean score of the model: 0.6499315381104519
# ViT-B/16 6573
# mean score of the model: 0.6499847885609978
# ViT-B/16 6574
# mean score of the model: 0.6498859315589354
# ViT-B/16 6575
# mean score of the model: 0.6499391727493917
# ViT-B/16 6576
# mean score of the model: 0.6499923977497339
# ViT-B/16 6577
# mean score of the model: 0.6500456065673457
# ViT-B/16 6578
# mean score of the model: 0.6499468004255966
# ViT-B/16 6579
# mean score of the model: 0.65
# ViT-B/16 6580
# mean score of the model: 0.6499012308159854
# ViT-B/16 6581
# mean score of the model: 0.649954421148587
# ViT-B/16 6582
# mean score of the model: 0.650007595321282
# ViT-B/16 6583
# mean score of the model: 0.6500607533414338
# ViT-B/16 6584
# mean score of the model: 0.650113895216401
# ViT-B/16 6585
# mean score of the model: 0.6500151837230489
# ViT-B/16 6586
# mean score of the model: 0.6500683163807499
# ViT-B/16 6587
# mean score of the model: 0.6499696417729205
# ViT-B/16 6588
# mean score of the model: 0.6500227652147519
# ViT-B/16 6589
# mean score of the model: 0.6500758725341427
# ViT-B/16 6590
# mean score of the model: 0.6501289637384312
# ViT-B/16 6591
# mean score of the model: 0.6501820388349514
# ViT-B/16 6592
# mean score of the model: 0.6500834218110116
# ViT-B/16 6593
# mean score of the model: 0.6499848346982104
# ViT-B/16 6594
# mean score of the model: 0.6498862774829416
# ViT-B/16 6595
# mean score of the model: 0.6499393571861735
# ViT-B/16 6596
# mean score of the model: 0.6499924207973321
# ViT-B/16 6597
# mean score of the model: 0.6498939072446196
# ViT-B/16 6598
# mean score of the model: 0.6499469616608577
# ViT-B/16 6599
# mean score of the model: 0.6498484848484849
# ViT-B/16 6600
# mean score of the model: 0.6497500378730495
# ViT-B/16 6601
# mean score of the model: 0.6498030899727355
# ViT-B/16 6602
# mean score of the model: 0.6498561260033319
# ViT-B/16 6603
# mean score of the model: 0.6499091459721381
# ViT-B/16 6604
# mean score of the model: 0.6499621498864496
# ViT-B/16 6605
# mean score of the model: 0.6498637602179836
# ViT-B/16 6606
# mean score of the model: 0.6497654003329801
# ViT-B/16 6607
# mean score of the model: 0.649818401937046
# ViT-B/16 6608
# mean score of the model: 0.6497200786805871
# ViT-B/16 6609
# mean score of the model: 0.6497730711043873
# ViT-B/16 6610
# mean score of the model: 0.6496747844501588
# ViT-B/16 6611
# mean score of the model: 0.6497277676950998
# ViT-B/16 6612
# mean score of the model: 0.6497807349160744
# ViT-B/16 6613
# mean score of the model: 0.6498336861203508
# ViT-B/16 6614
# mean score of the model: 0.6498866213151927
# ViT-B/16 6615
# mean score of the model: 0.649788391777509
# ViT-B/16 6616
# mean score of the model: 0.6496901919298775
# ViT-B/16 6617
# mean score of the model: 0.6497431248111212
# ViT-B/16 6618
# mean score of the model: 0.649644961474543
# ViT-B/16 6619
# mean score of the model: 0.6496978851963746
# ViT-B/16 6620
# mean score of the model: 0.6497507929315813
# ViT-B/16 6621
# mean score of the model: 0.6498036846874056
# ViT-B/16 6622
# mean score of the model: 0.6498565604710856
# ViT-B/16 6623
# mean score of the model: 0.6497584541062802
# ViT-B/16 6624
# mean score of the model: 0.6498113207547169
# ViT-B/16 6625
# mean score of the model: 0.6497132508300634
# ViT-B/16 6626
# mean score of the model: 0.6497661083446507
# ViT-B/16 6627
# mean score of the model: 0.649818949909475
# ViT-B/16 6628
# mean score of the model: 0.6498717755317545
# ViT-B/16 6629
# mean score of the model: 0.6499245852187029
# ViT-B/16 6630
# mean score of the model: 0.6498265721610617
# ViT-B/16 6631
# mean score of the model: 0.6498793727382388
# ViT-B/16 6632
# mean score of the model: 0.6497813960500528
# ViT-B/16 6633
# mean score of the model: 0.6498341875188424
# ViT-B/16 6634
# mean score of the model: 0.6497362471740769
# ViT-B/16 6635
# mean score of the model: 0.6497890295358649
# ViT-B/16 6636
# mean score of the model: 0.6496911255085129
# ViT-B/16 6637
# mean score of the model: 0.6495932509792106
# ViT-B/16 6638
# mean score of the model: 0.6494954059346287
# ViT-B/16 6639
# mean score of the model: 0.6493975903614457
# ViT-B/16 6640
# mean score of the model: 0.6494503839783166
# ViT-B/16 6641
# mean score of the model: 0.6495031616982837
# ViT-B/16 6642
# mean score of the model: 0.6495559235285263
# ViT-B/16 6643
# mean score of the model: 0.6496086694762191
# ViT-B/16 6644
# mean score of the model: 0.6496613995485327
# ViT-B/16 6645
# mean score of the model: 0.6495636473066506
# ViT-B/16 6646
# mean score of the model: 0.6494659244772077
# ViT-B/16 6647
# mean score of the model: 0.6495186522262335
# ViT-B/16 6648
# mean score of the model: 0.6494209655587306
# ViT-B/16 6649
# mean score of the model: 0.6494736842105263
# ViT-B/16 6650
# mean score of the model: 0.6495263870094723
# ViT-B/16 6651
# mean score of the model: 0.649579073962718
# ViT-B/16 6652
# mean score of the model: 0.6496317450774087
# ViT-B/16 6653
# mean score of the model: 0.6496844003606853
# ViT-B/16 6654
# mean score of the model: 0.6497370398196844
# ViT-B/16 6655
# mean score of the model: 0.6497896634615384
# ViT-B/16 6656
# mean score of the model: 0.6498422712933754
# ViT-B/16 6657
# mean score of the model: 0.649894863322319
# ViT-B/16 6658
# mean score of the model: 0.6499474395554888
# ViT-B/16 6659
# mean score of the model: 0.65
# ViT-B/16 6660
# mean score of the model: 0.6499024170544964
# ViT-B/16 6661
# mean score of the model: 0.6499549684779345
# ViT-B/16 6662
# mean score of the model: 0.64985742158187
# ViT-B/16 6663
# mean score of the model: 0.6499099639855942
# ViT-B/16 6664
# mean score of the model: 0.6499624906226557
# ViT-B/16 6665
# mean score of the model: 0.65001500150015
# ViT-B/16 6666
# mean score of the model: 0.6499175041247938
# ViT-B/16 6667
# mean score of the model: 0.6499700059988003
# ViT-B/16 6668
# mean score of the model: 0.6500224921277553
# ViT-B/16 6669
# mean score of the model: 0.6499250374812594
# ViT-B/16 6670
# mean score of the model: 0.6499775146154999
# ViT-B/16 6671
# mean score of the model: 0.6500299760191847
# ViT-B/16 6672
# mean score of the model: 0.6500824216993856
# ViT-B/16 6673
# mean score of the model: 0.6501348516631705
# ViT-B/16 6674
# mean score of the model: 0.650187265917603
# ViT-B/16 6675
# mean score of the model: 0.6500898741761534
# ViT-B/16 6676
# mean score of the model: 0.6501422794668265
# ViT-B/16 6677
# mean score of the model: 0.6500449236298292
# ViT-B/16 6678
# mean score of the model: 0.6499475969456505
# ViT-B/16 6679
# mean score of the model: 0.6498502994011977
# ViT-B/16 6680
# mean score of the model: 0.6497530309833858
# ViT-B/16 6681
# mean score of the model: 0.649655791679138
# ViT-B/16 6682
# mean score of the model: 0.6497082148735598
# ViT-B/16 6683
# mean score of the model: 0.6497606223818073
# ViT-B/16 6684
# mean score of the model: 0.64981301421092
# ViT-B/16 6685
# mean score of the model: 0.6497158241100808
# ViT-B/16 6686
# mean score of the model: 0.6497682069687454
# ViT-B/16 6687
# mean score of the model: 0.6498205741626795
# ViT-B/16 6688
# mean score of the model: 0.6498729256989086
# ViT-B/16 6689
# mean score of the model: 0.6497757847533633
# ViT-B/16 6690
# mean score of the model: 0.6498281273352264
# ViT-B/16 6691
# mean score of the model: 0.6497310221159593
# ViT-B/16 6692
# mean score of the model: 0.649783355744808
# ViT-B/16 6693
# mean score of the model: 0.6498356737376755
# ViT-B/16 6694
# mean score of the model: 0.6498879761015683
# ViT-B/16 6695
# mean score of the model: 0.6497909199522103
# ViT-B/16 6696
# mean score of the model: 0.649843213379125
# ViT-B/16 6697
# mean score of the model: 0.6498954911914004
# ViT-B/16 6698
# mean score of the model: 0.6499477533960293
# ViT-B/16 6699
# mean score of the model: 0.65
# ViT-B/16 6700
# mean score of the model: 0.650052231010297
# ViT-B/16 6701
# mean score of the model: 0.6501044464339003
# ViT-B/16 6702
# mean score of the model: 0.650156646277786
# ViT-B/16 6703
# mean score of the model: 0.6500596658711217
# ViT-B/16 6704
# mean score of the model: 0.6499627143922446
# ViT-B/16 6705
# mean score of the model: 0.6500149120190873
# ViT-B/16 6706
# mean score of the model: 0.6500670940808111
# ViT-B/16 6707
# mean score of the model: 0.6501192605843769
# ViT-B/16 6708
# mean score of the model: 0.6501714115367417
# ViT-B/16 6709
# mean score of the model: 0.6502235469448584
# ViT-B/16 6710
# mean score of the model: 0.6502756668156757
# ViT-B/16 6711
# mean score of the model: 0.6503277711561383
# ViT-B/16 6712
# mean score of the model: 0.6503798599731864
# ViT-B/16 6713
# mean score of the model: 0.6504319332737564
# ViT-B/16 6714
# mean score of the model: 0.6503350707371556
# ViT-B/16 6715
# mean score of the model: 0.6502382370458606
# ViT-B/16 6716
# mean score of the model: 0.6501414321869883
# ViT-B/16 6717
# mean score of the model: 0.6501935099732064
# ViT-B/16 6718
# mean score of the model: 0.6502455722577765
# ViT-B/16 6719
# mean score of the model: 0.6502976190476191
# ViT-B/16 6720
# mean score of the model: 0.6502008629668204
# ViT-B/16 6721
# mean score of the model: 0.6501041356739066
# ViT-B/16 6722
# mean score of the model: 0.6500074371560315
# ViT-B/16 6723
# mean score of the model: 0.6499107674003569
# ViT-B/16 6724
# mean score of the model: 0.6499628252788104
# ViT-B/16 6725
# mean score of the model: 0.6500148676776687
# ViT-B/16 6726
# mean score of the model: 0.6499182399286457
# ViT-B/16 6727
# mean score of the model: 0.6499702734839476
# ViT-B/16 6728
# mean score of the model: 0.6500222915737851
# ViT-B/16 6729
# mean score of the model: 0.650074294205052
# ViT-B/16 6730
# mean score of the model: 0.6501262813846382
# ViT-B/16 6731
# mean score of the model: 0.6500297088532383
# ViT-B/16 6732
# mean score of the model: 0.6500816872122382
# ViT-B/16 6733
# mean score of the model: 0.6501336501336501
# ViT-B/16 6734
# mean score of the model: 0.6501855976243504
# ViT-B/16 6735
# mean score of the model: 0.6502375296912114
# ViT-B/16 6736
# mean score of the model: 0.6502894463411014
# ViT-B/16 6737
# mean score of the model: 0.6501929355891956
# ViT-B/16 6738
# mean score of the model: 0.6500964534797448
# ViT-B/16 6739
# mean score of the model: 0.65
# ViT-B/16 6740
# mean score of the model: 0.6500519210799585
# ViT-B/16 6741
# mean score of the model: 0.6501038267576387
# ViT-B/16 6742
# mean score of the model: 0.6501557170398933
# ViT-B/16 6743
# mean score of the model: 0.6502075919335706
# ViT-B/16 6744
# mean score of the model: 0.6501111934766494
# ViT-B/16 6745
# mean score of the model: 0.6501630595908686
# ViT-B/16 6746
# mean score of the model: 0.6500666963094709
# ViT-B/16 6747
# mean score of the model: 0.6499703615886189
# ViT-B/16 6748
# mean score of the model: 0.6500222255148911
# ViT-B/16 6749
# mean score of the model: 0.650074074074074
# ViT-B/16 6750
# mean score of the model: 0.6499777810694712
# ViT-B/16 6751
# mean score of the model: 0.6500296208530806
# ViT-B/16 6752
# mean score of the model: 0.6499333629498001
# ViT-B/16 6753
# mean score of the model: 0.6499851939591353
# ViT-B/16 6754
# mean score of the model: 0.6500370096225019
# ViT-B/16 6755
# mean score of the model: 0.650088809946714
# ViT-B/16 6756
# mean score of the model: 0.6501405949385822
# ViT-B/16 6757
# mean score of the model: 0.6500443918319029
# ViT-B/16 6758
# mean score of the model: 0.6500961680722
# ViT-B/16 6759
# mean score of the model: 0.6501479289940828
# ViT-B/16 6760
# mean score of the model: 0.6501996746043485
# ViT-B/16 6761
# mean score of the model: 0.65025140490979
# ViT-B/16 6762
# mean score of the model: 0.6501552565429544
# ViT-B/16 6763
# mean score of the model: 0.6502069781194559
# ViT-B/16 6764
# mean score of the model: 0.6502586844050259
# ViT-B/16 6765
# mean score of the model: 0.650310375406444
# ViT-B/16 6766
# mean score of the model: 0.6502142751588592
# ViT-B/16 6767
# mean score of the model: 0.6502659574468085
# ViT-B/16 6768
# mean score of the model: 0.6503176244644704
# ViT-B/16 6769
# mean score of the model: 0.6503692762186115
# ViT-B/16 6770
# mean score of the model: 0.6504209127159947
# ViT-B/16 6771
# mean score of the model: 0.6504725339633786
# ViT-B/16 6772
# mean score of the model: 0.6505241399675181
# ViT-B/16 6773
# mean score of the model: 0.6505757307351638
# ViT-B/16 6774
# mean score of the model: 0.650479704797048
# ViT-B/16 6775
# mean score of the model: 0.6505312868949232
# ViT-B/16 6776
# mean score of the model: 0.6505828537701047
# ViT-B/16 6777
# mean score of the model: 0.6504868692829743
# ViT-B/16 6778
# mean score of the model: 0.6505384274966809
# ViT-B/16 6779
# mean score of the model: 0.6505899705014749
# ViT-B/16 6780
# mean score of the model: 0.6504940274295826
# ViT-B/16 6781
# mean score of the model: 0.6505455617811855
# ViT-B/16 6782
# mean score of the model: 0.6505970809376382
# ViT-B/16 6783
# mean score of the model: 0.6506485849056604
# ViT-B/16 6784
# mean score of the model: 0.6507000736919676
# ViT-B/16 6785
# mean score of the model: 0.6507515473032714
# ViT-B/16 6786
# mean score of the model: 0.6506556652423752
# ViT-B/16 6787
# mean score of the model: 0.6505598114319388
# ViT-B/16 6788
# mean score of the model: 0.6504639858594786
# ViT-B/16 6789
# mean score of the model: 0.6505154639175258
# ViT-B/16 6790
# mean score of the model: 0.6504196730967456
# ViT-B/16 6791
# mean score of the model: 0.650323910482921
# ViT-B/16 6792
# mean score of the model: 0.6502281760635948
# ViT-B/16 6793
# mean score of the model: 0.6501324698263173
# ViT-B/16 6794
# mean score of the model: 0.650036791758646
# ViT-B/16 6795
# mean score of the model: 0.650088287227781
# ViT-B/16 6796
# mean score of the model: 0.650139767544505
# ViT-B/16 6797
# mean score of the model: 0.6501912327155046
# ViT-B/16 6798
# mean score of the model: 0.6502426827474629
# ViT-B/16 6799
# mean score of the model: 0.6501470588235294
# ViT-B/16 6800
# mean score of the model: 0.6501985002205558
# ViT-B/16 6801
# mean score of the model: 0.6501029109085563
# ViT-B/16 6802
# mean score of the model: 0.6500073496986624
# ViT-B/16 6803
# mean score of the model: 0.6500587889476779
# ViT-B/16 6804
# mean score of the model: 0.6501102130786187
# ViT-B/16 6805
# mean score of the model: 0.6501616220981487
# ViT-B/16 6806
# mean score of the model: 0.6500661084178052
# ViT-B/16 6807
# mean score of the model: 0.650117508813161
# ViT-B/16 6808
# mean score of the model: 0.6501688941107358
# ViT-B/16 6809
# mean score of the model: 0.6502202643171806
# ViT-B/16 6810
# mean score of the model: 0.6502716194391426
# ViT-B/16 6811
# mean score of the model: 0.6503229594832648
# ViT-B/16 6812
# mean score of the model: 0.6503742844561867
# ViT-B/16 6813
# mean score of the model: 0.6504255943645436
# ViT-B/16 6814
# mean score of the model: 0.6504768892149669
# ViT-B/16 6815
# mean score of the model: 0.650381455399061
# ViT-B/16 6816
# mean score of the model: 0.6504327416752237
# ViT-B/16 6817
# mean score of the model: 0.6503373423291288
# ViT-B/16 6818
# mean score of the model: 0.6503886200322628
# ViT-B/16 6819
# mean score of the model: 0.6504398826979472
# ViT-B/16 6820
# mean score of the model: 0.6503445242633045
# ViT-B/16 6821
# mean score of the model: 0.6503957783641161
# ViT-B/16 6822
# mean score of the model: 0.6504470174410083
# ViT-B/16 6823
# mean score of the model: 0.6503516998827668
# ViT-B/16 6824
# mean score of the model: 0.6504029304029304
# ViT-B/16 6825
# mean score of the model: 0.6504541459126868
# ViT-B/16 6826
# mean score of the model: 0.6505053464186319
# ViT-B/16 6827
# mean score of the model: 0.650556531927358
# ViT-B/16 6828
# mean score of the model: 0.6504612681212476
# ViT-B/16 6829
# mean score of the model: 0.6505124450951684
# ViT-B/16 6830
# mean score of the model: 0.650417215634607
# ViT-B/16 6831
# mean score of the model: 0.6503220140515222
# ViT-B/16 6832
# mean score of the model: 0.6502268403336748
# ViT-B/16 6833
# mean score of the model: 0.6502780216564238
# ViT-B/16 6834
# mean score of the model: 0.6503291880029262
# ViT-B/16 6835
# mean score of the model: 0.6502340550029256
# ViT-B/16 6836
# mean score of the model: 0.6502852128126371
# ViT-B/16 6837
# mean score of the model: 0.6501901140684411
# ViT-B/16 6838
# mean score of the model: 0.6500950431349612
# ViT-B/16 6839
# mean score of the model: 0.6501461988304094
# ViT-B/16 6840
# mean score of the model: 0.6500511621108025
# ViT-B/16 6841
# mean score of the model: 0.6501023092662964
# ViT-B/16 6842
# mean score of the model: 0.6501534414730381
# ViT-B/16 6843
# mean score of the model: 0.6500584453535944
# ViT-B/16 6844
# mean score of the model: 0.649963476990504
# ViT-B/16 6845
# mean score of the model: 0.6500146070698218
# ViT-B/16 6846
# mean score of the model: 0.6499196728494231
# ViT-B/16 6847
# mean score of the model: 0.6499707943925234
# ViT-B/16 6848
# mean score of the model: 0.6498758942911373
# ViT-B/16 6849
# mean score of the model: 0.6499270072992701
# ViT-B/16 6850
# mean score of the model: 0.649978105386075
# ViT-B/16 6851
# mean score of the model: 0.6500291885580852
# ViT-B/16 6852
# mean score of the model: 0.6500802568218299
# ViT-B/16 6853
# mean score of the model: 0.6501313101838343
# ViT-B/16 6854
# mean score of the model: 0.65018234865062
# ViT-B/16 6855
# mean score of the model: 0.6502333722287048
# ViT-B/16 6856
# mean score of the model: 0.6502843809246026
# ViT-B/16 6857
# mean score of the model: 0.6503353747448236
# ViT-B/16 6858
# mean score of the model: 0.650386353695874
# ViT-B/16 6859
# mean score of the model: 0.6504373177842565
# ViT-B/16 6860
# mean score of the model: 0.65034251566827
# ViT-B/16 6861
# mean score of the model: 0.6503934712911688
# ViT-B/16 6862
# mean score of the model: 0.6504444120646947
# ViT-B/16 6863
# mean score of the model: 0.650495337995338
# ViT-B/16 6864
# mean score of the model: 0.6505462490895848
# ViT-B/16 6865
# mean score of the model: 0.6505971453539179
# ViT-B/16 6866
# mean score of the model: 0.6505024027959808
# ViT-B/16 6867
# mean score of the model: 0.6504076878276063
# ViT-B/16 6868
# mean score of the model: 0.6504585820352308
# ViT-B/16 6869
# mean score of the model: 0.650509461426492
# ViT-B/16 6870
# mean score of the model: 0.6505603260078591
# ViT-B/16 6871
# mean score of the model: 0.6506111757857974
# ViT-B/16 6872
# mean score of the model: 0.6506620107667686
# ViT-B/16 6873
# mean score of the model: 0.6507128309572301
# ViT-B/16 6874
# mean score of the model: 0.6506181818181819
# ViT-B/16 6875
# mean score of the model: 0.6506689936009308
# ViT-B/16 6876
# mean score of the model: 0.6505743783626582
# ViT-B/16 6877
# mean score of the model: 0.650479790636813
# ViT-B/16 6878
# mean score of the model: 0.650385230411397
# ViT-B/16 6879
# mean score of the model: 0.6504360465116279
# ViT-B/16 6880
# mean score of the model: 0.6503415201278884
# ViT-B/16 6881
# mean score of the model: 0.6503923278116827
# ViT-B/16 6882
# mean score of the model: 0.6504431207322389
# ViT-B/16 6883
# mean score of the model: 0.6504938988959907
# ViT-B/16 6884
# mean score of the model: 0.6505446623093681
# ViT-B/16 6885
# mean score of the model: 0.6505954109787976
# ViT-B/16 6886
# mean score of the model: 0.6505009438071729
# ViT-B/16 6887
# mean score of the model: 0.6505516840882695
# ViT-B/16 6888
# mean score of the model: 0.650457250689505
# ViT-B/16 6889
# mean score of the model: 0.6505079825834543
# ViT-B/16 6890
# mean score of the model: 0.6505586997533014
# ViT-B/16 6891
# mean score of the model: 0.6504643064422518
# ViT-B/16 6892
# mean score of the model: 0.6503699405193675
# ViT-B/16 6893
# mean score of the model: 0.6504206556425878
# ViT-B/16 6894
# mean score of the model: 0.6503263234227701
# ViT-B/16 6895
# mean score of the model: 0.6502320185614849
# ViT-B/16 6896
# mean score of the model: 0.650137741046832
# ViT-B/16 6897
# mean score of the model: 0.6501884604233111
# ViT-B/16 6898
# mean score of the model: 0.6500942165531236
# ViT-B/16 6899
# mean score of the model: 0.6501449275362319
# ViT-B/16 6900
# mean score of the model: 0.6501956238226344
# ViT-B/16 6901
# mean score of the model: 0.6502463054187192
# ViT-B/16 6902
# mean score of the model: 0.6502969723308706
# ViT-B/16 6903
# mean score of the model: 0.6503476245654692
# ViT-B/16 6904
# mean score of the model: 0.6503982621288921
# ViT-B/16 6905
# mean score of the model: 0.6503040834057341
# ViT-B/16 6906
# mean score of the model: 0.6502099319530911
# ViT-B/16 6907
# mean score of the model: 0.6502605674580196
# ViT-B/16 6908
# mean score of the model: 0.6503111883051093
# ViT-B/16 6909
# mean score of the model: 0.6502170767004342
# ViT-B/16 6910
# mean score of the model: 0.6501229923310664
# ViT-B/16 6911
# mean score of the model: 0.6501736111111112
# ViT-B/16 6912
# mean score of the model: 0.6502242152466368
# ViT-B/16 6913
# mean score of the model: 0.6502748047439977
# ViT-B/16 6914
# mean score of the model: 0.6503253796095445
# ViT-B/16 6915
# mean score of the model: 0.6502313475997686
# ViT-B/16 6916
# mean score of the model: 0.6501373427786613
# ViT-B/16 6917
# mean score of the model: 0.6501879155825383
# ViT-B/16 6918
# mean score of the model: 0.6502384737678856
# ViT-B/16 6919
# mean score of the model: 0.6502890173410405
# ViT-B/16 6920
# mean score of the model: 0.6501950585175552
# ViT-B/16 6921
# mean score of the model: 0.6502455937590291
# ViT-B/16 6922
# mean score of the model: 0.6501516683518705
# ViT-B/16 6923
# mean score of the model: 0.6500577700751011
# ViT-B/16 6924
# mean score of the model: 0.6499638989169675
# ViT-B/16 6925
# mean score of the model: 0.6498700548657234
# ViT-B/16 6926
# mean score of the model: 0.649920600548578
# ViT-B/16 6927
# mean score of the model: 0.6499711316397229
# ...
# ViT-B/16 8323
# mean score of the model: 0.6528111484863046
# ViT-B/16 8324
# mean score of the model: 0.6527327327327327
# ViT-B/16 8325
# mean score of the model: 0.6527744415085275
# ViT-B/16 8326
# mean score of the model: 0.6528161402666026
# ViT-B/16 8327
# mean score of the model: 0.6527377521613833
# ViT-B/16 8328
# mean score of the model: 0.6527794453115621
# ViT-B/16 8329
# mean score of the model: 0.6528211284513805
# ViT-B/16 8330
# mean score of the model: 0.6528628015844437
# ViT-B/16 8331
# mean score of the model: 0.6529044647143543
# ViT-B/16 8332
# mean score of the model: 0.6528261130445218
# ViT-B/16 8333
# mean score of the model: 0.6528677705783538
# ViT-B/16 8334
# mean score of the model: 0.6529094181163767
# ViT-B/16 8335
# mean score of the model: 0.6529510556621881
# ViT-B/16 8336
# mean score of the model: 0.6529926832193834
# ViT-B/16 8337
# mean score of the model: 0.6530343007915568
# ViT-B/16 8338
# mean score of the model: 0.6530759083823
# ViT-B/16 8339
# mean score of the model: 0.6531175059952038
# ViT-B/16 8340
# mean score of the model: 0.6531590936338568
# ViT-B/16 8341
# mean score of the model: 0.6532006713018461
# ViT-B/16 8342
# mean score of the model: 0.6531223780414719
# ViT-B/16 8343
# mean score of the model: 0.6530441035474592
# ViT-B/16 8344
# mean score of the model: 0.6529658478130617
# ViT-B/16 8345
# mean score of the model: 0.652887610831536
# ViT-B/16 8346
# mean score of the model: 0.6529291961183659
# ViT-B/16 8347
# mean score of the model: 0.6529707714422616
# ViT-B/16 8348
# mean score of the model: 0.6528925619834711
# ViT-B/16 8349
# mean score of the model: 0.6529341317365269
# ViT-B/16 8350
# mean score of the model: 0.6529756915339481
# ViT-B/16 8351
# mean score of the model: 0.6530172413793104
# ViT-B/16 8352
# mean score of the model: 0.6530587812761882
# ViT-B/16 8353
# mean score of the model: 0.6531003112281542
# ViT-B/16 8354
# mean score of the model: 0.6530221424296828
# ViT-B/16 8355
# mean score of the model: 0.6530636668262326
# ViT-B/16 8356
# mean score of the model: 0.6529855211200192
# ViT-B/16 8357
# mean score of the model: 0.6530270399617133
# ViT-B/16 8358
# mean score of the model: 0.653068548869482
# ViT-B/16 8359
# mean score of the model: 0.65311004784689
# ViT-B/16 8360
# mean score of the model: 0.6531515368975003
# ViT-B/16 8361
# mean score of the model: 0.6531930160248745
# ViT-B/16 8362
# mean score of the model: 0.653114910917135
# ViT-B/16 8363
# mean score of the model: 0.653036824485892
# ViT-B/16 8364
# mean score of the model: 0.6530783024506874
# ViT-B/16 8365
# mean score of the model: 0.6530002390628735
# ViT-B/16 8366
# mean score of the model: 0.6530417114855982
# ViT-B/16 8367
# mean score of the model: 0.6530831739961759
# ViT-B/16 8368
# mean score of the model: 0.6531246265981598
# ViT-B/16 8369
# mean score of the model: 0.6531660692951016
# ViT-B/16 8370
# mean score of the model: 0.6532075020905507
# ViT-B/16 8371
# mean score of the model: 0.6532489249880554
# ViT-B/16 8372
# mean score of the model: 0.6532903379911621
# ViT-B/16 8373
# mean score of the model: 0.6532123238595653
# ViT-B/16 8374
# mean score of the model: 0.6532537313432836
# ViT-B/16 8375
# mean score of the model: 0.6531757402101241
# ViT-B/16 8376
# mean score of the model: 0.6532171421750029
# ViT-B/16 8377
# mean score of the model: 0.6532585342563858
# ViT-B/16 8378
# mean score of the model: 0.6532999164578112
# ViT-B/16 8379
# mean score of the model: 0.6533412887828163
# ViT-B/16 8380
# mean score of the model: 0.6532633337310584
# ViT-B/16 8381
# mean score of the model: 0.6533047005487951
# ViT-B/16 8382
# mean score of the model: 0.653346057497316
# ViT-B/16 8383
# mean score of the model: 0.6532681297709924
# ViT-B/16 8384
# mean score of the model: 0.6533094812164579
# ViT-B/16 8385
# mean score of the model: 0.6533508227999046
# ViT-B/16 8386
# mean score of the model: 0.6533921545248599
# ViT-B/16 8387
# mean score of the model: 0.6533142584644731
# ViT-B/16 8388
# mean score of the model: 0.6533555846942425
# ViT-B/16 8389
# mean score of the model: 0.6532777115613826
# ViT-B/16 8390
# mean score of the model: 0.6533190322965081
# ViT-B/16 8391
# mean score of the model: 0.6533603431839847
# ViT-B/16 8392
# mean score of the model: 0.6534016442273323
# ViT-B/16 8393
# mean score of the model: 0.6534429354300691
# ViT-B/16 8394
# mean score of the model: 0.6533650982727814
# ViT-B/16 8395
# mean score of the model: 0.6532872796569795
# ViT-B/16 8396
# mean score of the model: 0.653209479576039
# ViT-B/16 8397
# mean score of the model: 0.6531316980233389
# ViT-B/16 8398
# mean score of the model: 0.6531729967853316
# ViT-B/16 8399
# mean score of the model: 0.6532142857142857
# ViT-B/16 8400
# mean score of the model: 0.6532555648137126
# ViT-B/16 8401
# mean score of the model: 0.6531778148059986
# ViT-B/16 8402
# mean score of the model: 0.6532190884208021
# ViT-B/16 8403
# mean score of the model: 0.6532603522132318
# ViT-B/16 8404
# mean score of the model: 0.6533016061867936
# ViT-B/16 8405
# mean score of the model: 0.6532238876992624
# ViT-B/16 8406
# mean score of the model: 0.6532651361960271
# ViT-B/16 8407
# mean score of the model: 0.6533063748810657
# ViT-B/16 8408
# mean score of the model: 0.6532286835533357
# ViT-B/16 8409
# mean score of the model: 0.6531510107015458
# ViT-B/16 8410
# mean score of the model: 0.653192248246344
# ViT-B/16 8411
# mean score of the model: 0.6532334759866857
# ViT-B/16 8412
# mean score of the model: 0.6531558302626886
# ViT-B/16 8413
# mean score of the model: 0.6530782029950083
# ViT-B/16 8414
# mean score of the model: 0.6531194295900178
# ViT-B/16 8415
# mean score of the model: 0.6531606463878327
# ViT-B/16 8416
# mean score of the model: 0.6530830462159914
# ViT-B/16 8417
# mean score of the model: 0.6531242575433595
# ViT-B/16 8418
# mean score of the model: 0.6530466801282813
# ViT-B/16 8419
# mean score of the model: 0.6529691211401425
# ViT-B/16 8420
# mean score of the model: 0.6528915805723786
# ViT-B/16 8421
# mean score of the model: 0.6529327950605557
# ViT-B/16 8422
# mean score of the model: 0.6529739997625549
# ViT-B/16 8423
# mean score of the model: 0.6530151946818613
# ViT-B/16 8424
# mean score of the model: 0.6530563798219584
# ViT-B/16 8425
# mean score of the model: 0.6529788749109898
# ViT-B/16 8426
# mean score of the model: 0.6530200545864483
# ViT-B/16 8427
# mean score of the model: 0.6530612244897959
# ViT-B/16 8428
# mean score of the model: 0.6531023846245106
# ViT-B/16 8429
# mean score of the model: 0.6531435349940689
# ViT-B/16 8430
# mean score of the model: 0.6530660657098802
# ViT-B/16 8431
# mean score of the model: 0.652988614800759
# ViT-B/16 8432
# mean score of the model: 0.6529111822601684
# ViT-B/16 8433
# mean score of the model: 0.6528337680815746
# ViT-B/16 8434
# mean score of the model: 0.652756372258447
# ViT-B/16 8435
# mean score of the model: 0.6527975343764817
# ViT-B/16 8436
# mean score of the model: 0.6528386867369919
# ViT-B/16 8437
# mean score of the model: 0.6528798293434463
# ViT-B/16 8438
# mean score of the model: 0.652802464747008
# ViT-B/16 8439
# mean score of the model: 0.6528436018957346
# ViT-B/16 8440
# mean score of the model: 0.6528847292974767
# ViT-B/16 8441
# mean score of the model: 0.6529258469556977
# ViT-B/16 8442
# mean score of the model: 0.65296695487386
# ViT-B/16 8443
# mean score of the model: 0.653008053055424
# ViT-B/16 8444
# mean score of the model: 0.6530491415038484
# ViT-B/16 8445
# mean score of the model: 0.6530902202225906
# ViT-B/16 8446
# mean score of the model: 0.653131289215106
# ViT-B/16 8447
# mean score of the model: 0.6531723484848485
# ViT-B/16 8448
# mean score of the model: 0.6530950408332347
# ViT-B/16 8449
# mean score of the model: 0.65301775147929
# ViT-B/16 8450
# mean score of the model: 0.6530588096083304
# ViT-B/16 8451
# mean score of the model: 0.65309985802177
# ViT-B/16 8452
# mean score of the model: 0.6531408967230569
# ViT-B/16 8453
# mean score of the model: 0.6531819257156376
# ViT-B/16 8454
# mean score of the model: 0.6532229450029569
# ViT-B/16 8455
# mean score of the model: 0.6531456953642384
# ViT-B/16 8456
# mean score of the model: 0.6531867092349533
# ViT-B/16 8457
# mean score of the model: 0.6532277134074249
# ViT-B/16 8458
# mean score of the model: 0.6532687078850928
# ViT-B/16 8459
# mean score of the model: 0.6533096926713948
# ViT-B/16 8460
# mean score of the model: 0.6533506677697671
# ViT-B/16 8461
# mean score of the model: 0.6533916331836446
# ViT-B/16 8462
# mean score of the model: 0.6534325889164598
# ViT-B/16 8463
# mean score of the model: 0.6534735349716446
# ViT-B/16 8464
# mean score of the model: 0.6535144713526285
# ViT-B/16 8465
# mean score of the model: 0.6534372785258682
# ViT-B/16 8466
# mean score of the model: 0.653360103932916
# ViT-B/16 8467
# mean score of the model: 0.6534010392064242
# ViT-B/16 8468
# mean score of the model: 0.6534419648128469
# ViT-B/16 8469
# mean score of the model: 0.653482880755608
# ViT-B/16 8470
# mean score of the model: 0.6534057372211073
# ViT-B/16 8471
# mean score of the model: 0.6534466477809254
# ViT-B/16 8472
# mean score of the model: 0.6534875486840552
# ViT-B/16 8473
# mean score of the model: 0.6534104319093699
# ViT-B/16 8474
# mean score of the model: 0.6534513274336283
# ViT-B/16 8475
# mean score of the model: 0.6534922133081642
# ViT-B/16 8476
# mean score of the model: 0.6535330895363926
# ViT-B/16 8477
# mean score of the model: 0.6535739561217269
# ViT-B/16 8478
# mean score of the model: 0.6534968746314423
# ViT-B/16 8479
# mean score of the model: 0.6535377358490566
# ViT-B/16 8480
# mean score of the model: 0.6534606768069803
# ViT-B/16 8481
# mean score of the model: 0.6535015326573921
# ViT-B/16 8482
# mean score of the model: 0.6535423788753979
# ViT-B/16 8483
# mean score of the model: 0.6535832154644036
# ViT-B/16 8484
# mean score of the model: 0.6535061873895109
# ViT-B/16 8485
# mean score of the model: 0.653429177468772
# ViT-B/16 8486
# mean score of the model: 0.65335218569577
# ViT-B/16 8487
# mean score of the model: 0.6533930254476908
# ViT-B/16 8488
# mean score of the model: 0.6534338555778065
# ViT-B/16 8489
# mean score of the model: 0.653474676089517
# ViT-B/16 8490
# mean score of the model: 0.6535154869862208
# ViT-B/16 8491
# mean score of the model: 0.6535562882713142
# ViT-B/16 8492
# mean score of the model: 0.6535970799481926
# ViT-B/16 8493
# mean score of the model: 0.6536378620202495
# ViT-B/16 8494
# mean score of the model: 0.6535609181871689
# ViT-B/16 8495
# mean score of the model: 0.6534839924670434
# ViT-B/16 8496
# mean score of the model: 0.6534070848534776
# ViT-B/16 8497
# mean score of the model: 0.6534478700870793
# ViT-B/16 8498
# mean score of the model: 0.6533709848217437
# ViT-B/16 8499
# mean score of the model: 0.6532941176470588
# ViT-B/16 8500
# mean score of the model: 0.6533349017762616
# ViT-B/16 8501
# mean score of the model: 0.6533756763114561
# ViT-B/16 8502
# mean score of the model: 0.6534164412560273
# ViT-B/16 8503
# mean score of the model: 0.6533396048918156
# ViT-B/16 8504
# mean score of the model: 0.6533803644914756
# ViT-B/16 8505
# mean score of the model: 0.6534211145074066
# ViT-B/16 8506
# mean score of the model: 0.6534618549429881
# ViT-B/16 8507
# mean score of the model: 0.6533850493653033
# ViT-B/16 8508
# mean score of the model: 0.6534257844635092
# ViT-B/16 8509
# mean score of the model: 0.6534665099882491
# ViT-B/16 8510
# mean score of the model: 0.6535072259428975
# ViT-B/16 8511
# mean score of the model: 0.6535479323308271
# ViT-B/16 8512
# mean score of the model: 0.6535886291554094
# ViT-B/16 8513
# mean score of the model: 0.6536293164200141
# ViT-B/16 8514
# mean score of the model: 0.6535525543159131
# ViT-B/16 8515
# mean score of the model: 0.6535932362611555
# ViT-B/16 8516
# mean score of the model: 0.6536339086532816
# ViT-B/16 8517
# mean score of the model: 0.6536745714956562
# ViT-B/16 8518
# mean score of the model: 0.6537152247916422
# ViT-B/16 8519
# mean score of the model: 0.653755868544601
# ViT-B/16 8520
# mean score of the model: 0.653679145640183
# ViT-B/16 8521
# mean score of the model: 0.6537197840882422
# ViT-B/16 8522
# mean score of the model: 0.6537604130001173
# ViT-B/16 8523
# mean score of the model: 0.6538010323791648
# ViT-B/16 8524
# mean score of the model: 0.653724340175953
# ViT-B/16 8525
# mean score of the model: 0.6536476659629369
# ViT-B/16 8526
# mean score of the model: 0.6535710097337868
# ViT-B/16 8527
# mean score of the model: 0.6534943714821764
# ViT-B/16 8528
# mean score of the model: 0.6535349982412945
# ViT-B/16 8529
# mean score of the model: 0.6535756154747948
# ViT-B/16 8530
# mean score of the model: 0.6536162231860274
# ViT-B/16 8531
# mean score of the model: 0.6536568213783404
# ViT-B/16 8532
# mean score of the model: 0.6535802179772647
# ViT-B/16 8533
# mean score of the model: 0.6535036325287087
# ViT-B/16 8534
# mean score of the model: 0.6535442296426479
# ViT-B/16 8535
# mean score of the model: 0.653584817244611
# ViT-B/16 8536
# mean score of the model: 0.6535082581703174
# ViT-B/16 8537
# mean score of the model: 0.6535488404778637
# ViT-B/16 8538
# mean score of the model: 0.6535894132802436
# ViT-B/16 8539
# mean score of the model: 0.6535128805620609
# ViT-B/16 8540
# mean score of the model: 0.6535534480739961
# ViT-B/16 8541
# mean score of the model: 0.6535940060875673
# ViT-B/16 8542
# mean score of the model: 0.6535174997073627
# ViT-B/16 8543
# mean score of the model: 0.653558052434457
# ViT-B/16 8544
# mean score of the model: 0.6534815681685197
# ViT-B/16 8545
# mean score of the model: 0.6534051018020126
# ViT-B/16 8546
# mean score of the model: 0.6534456534456534
# ViT-B/16 8547
# mean score of the model: 0.6534861956013103
# ViT-B/16 8548
# mean score of the model: 0.6534097555269622
# ViT-B/16 8549
# mean score of the model: 0.6533333333333333
# ViT-B/16 8550
# mean score of the model: 0.6533738744006549
# ViT-B/16 8551
# mean score of the model: 0.6532974742750234
# ViT-B/16 8552
# mean score of the model: 0.6533380100549515
# ViT-B/16 8553
# mean score of the model: 0.6533785363572597
# ViT-B/16 8554
# mean score of the model: 0.653302162478083
# ViT-B/16 8555
# mean score of the model: 0.6532258064516129
# ViT-B/16 8556
# mean score of the model: 0.6532663316582915
# ViT-B/16 8557
# mean score of the model: 0.653306847394251
# ViT-B/16 8558
# mean score of the model: 0.6532305175838299
# ViT-B/16 8559
# mean score of the model: 0.6531542056074766
# ViT-B/16 8560
# mean score of the model: 0.6531947202429623
# ViT-B/16 8561
# mean score of the model: 0.6532352254146228
# ViT-B/16 8562
# mean score of the model: 0.6531589396239635
# ViT-B/16 8563
# mean score of the model: 0.6531994395142456
# ViT-B/16 8564
# mean score of the model: 0.6532399299474606
# ViT-B/16 8565
# mean score of the model: 0.6532804109269204
# ViT-B/16 8566
# mean score of the model: 0.6532041554803315
# ViT-B/16 8567
# mean score of the model: 0.6532446311858077
# ViT-B/16 8568
# mean score of the model: 0.6531683977126853
# ViT-B/16 8569
# mean score of the model: 0.6532088681446908
# ViT-B/16 8570
# mean score of the model: 0.6532493291331233
# ViT-B/16 8571
# mean score of the model: 0.653289780681288
# ViT-B/16 8572
# mean score of the model: 0.6532135775107897
# ViT-B/16 8573
# mean score of the model: 0.6532540237928621
# ViT-B/16 8574
# mean score of the model: 0.6532944606413994
# ViT-B/16 8575
# mean score of the model: 0.6533348880597015
# ViT-B/16 8576
# mean score of the model: 0.6532587151684738
# ViT-B/16 8577
# mean score of the model: 0.6532991373280485
# ViT-B/16 8578
# mean score of the model: 0.6532229863620469
# ViT-B/16 8579
# mean score of the model: 0.6531468531468532
# ViT-B/16 8580
# mean score of the model: 0.653187274210465
# ViT-B/16 8581
# mean score of the model: 0.6531111628990911
# ViT-B/16 8582
# mean score of the model: 0.6531515787020855
# ViT-B/16 8583
# mean score of the model: 0.6531919850885368
# ViT-B/16 8584
# mean score of the model: 0.6532323820617356
# ViT-B/16 8585
# mean score of the model: 0.6532727696249708
# ViT-B/16 8586
# mean score of the model: 0.6533131477815303
# ViT-B/16 8587
# mean score of the model: 0.6532370749883558
# ViT-B/16 8588
# mean score of the model: 0.6531610199091862
# ViT-B/16 8589
# mean score of the model: 0.6532013969732247
# ViT-B/16 8590
# mean score of the model: 0.6532417646374112
# ViT-B/16 8591
# mean score of the model: 0.6531657355679702
# ViT-B/16 8592
# mean score of the model: 0.6532060979867333
# ViT-B/16 8593
# mean score of the model: 0.6532464510123341
# ViT-B/16 8594
# mean score of the model: 0.6532867946480512
# ViT-B/16 8595
# mean score of the model: 0.653210795718939
# ViT-B/16 8596
# mean score of the model: 0.6532511341165523
# ViT-B/16 8597
# mean score of the model: 0.6531751570132589
# ViT-B/16 8598
# mean score of the model: 0.653215490173276
# ViT-B/16 8599

# %%
w

# %% [markdown]
# # All explanations

# %%
from captum.attr import *

zoo = modelvshuman.models.pytorch.model_zoo
BATCH_SIZE = 32

for MODEL_NAME in models.list_models("pytorch"):
  if 'clipR' not in MODEL_NAME:
    continue 
  print(MODEL_NAME)
  modelclip = getattr(zoo, MODEL_NAME)(MODEL_NAME)
  zeroshot_weights = modelclip.zeroshot_weights
  model = modelclip.model.cuda()

  # !rm -rf explanations
  # !mkdir explanations

  RESULTS = []
  img_passed = 0
  ds = get_dataset(BATCH_SIZE, True)
  REDUCERS = [1, 4, 16]

  last_conv = find_last_conv_layer(model)
  gc_explainer = LayerGradCam(model, last_conv)
  ig = IntegratedGradients(model)
  sa_explainer = Saliency(model)
  sg_explainer = NoiseTunnel(sa_explainer)
  oc_explainer = Occlusion(model)

  for x_batch, h_batch, y_batch in ds:

    x_batch = _tf_to_torch(x_batch)
    y_batch = _tf_to_torch(y_batch)
    y_ohe   = torch.argmax(y_batch, axis=-1)

    sa_phi = saliency(model, x_batch, y_batch,clip=True,zsw = zeroshot_weights)
    gi_phi = sa_phi * x_batch
    ig_phi = ig.attribute(x_batch, target = y_ohe, internal_batch_size = BATCH_SIZE // 2, n_steps = 30)
    sg_phi = sg_explainer.attribute(x_batch, nt_type='smoothgrad', stdevs=5.0, nt_samples=50, target=y_ohe, nt_samples_batch_size = BATCH_SIZE // 2)
    oc_phi = oc_explainer.attribute(x_batch, (3, 40, 40), (3, 20, 20), 0.0, target = y_ohe)

    sa_phi = torch.abs(torch.mean(sa_phi, axis=1))
    gi_phi = torch.abs(torch.mean(gi_phi, axis=1))
    ig_phi = torch.abs(torch.mean(ig_phi, axis=1))
    sg_phi = torch.abs(torch.mean(sg_phi, axis=1))
    oc_phi = torch.mean(oc_phi, axis=1)

    gc_phi = gc_explainer.attribute(x_batch, y_ohe)
    gc_phi = _torch_to_tf(gc_phi)
    gc_phi = tf.image.resize(gc_phi, (224, 224)).numpy()

    label = _torch_to_tf(y_batch)
    label = np.argmax(label, -1)

    for phi_name, phi in [('saliency', sa_phi), ('gradinput', gi_phi), ('gradcam', gc_phi), 
                          ('integrad', ig_phi), ('smoothgrad', sg_phi), ('occlusion', oc_phi)]:

      dice_score = dice(_torch_to_tf(phi), h_batch, reducers = REDUCERS)
      spearman_score = spearmanr_sim(_torch_to_tf(phi), h_batch, reducers = REDUCERS)
      iou_score = iou(_torch_to_tf(phi), h_batch, reducers = REDUCERS)

      # saving scores
      for metric_name, scores in [('dice', dice_score), ('spearman', spearman_score), ('iou', iou_score)]:
        for reducer_key in REDUCERS:
          for img_i in range(len(scores[reducer_key])):
            img_id = img_passed + img_i
            RESULTS.append((MODEL_NAME, phi_name, img_id, label[img_i], metric_name, reducer_key, scores[reducer_key][img_i].astype(np.float16)))
      
      # saving explanations
      phi = _torch_to_tf(phi)
      for pid, p in enumerate(phi):
        p -= p.min()
        p /= p.max()
        p *= 255.0

        img_id = pid + img_passed
        cv2.imwrite(f"explanations/{MODEL_NAME}_{phi_name}_{img_id}_{label[pid]}.png",  p.astype(np.uint8))
      
      set_size(10, 4)
      
      for i in range(3):
        plt.subplot(1, 2, 1)
        show(x_batch[i])
        show(phi[i], cmap='jet', p=1, smooth=3.0, alpha=0.35)
        
        plt.subplot(1, 2, 2)
        show(x_batch[i])
        show(h_batch[i], p=False, smooth=False, cmap='jet', alpha=0.35)
        plt.title(phi_name)    
        plt.show()
    
    img_passed += len(x_batch)
    print(MODEL_NAME, img_passed)

  bucket_name = "serrelab/prj_metapredictor"

  res = pd.DataFrame(RESULTS, columns=[
                                      'model name', 
                                      'attribution name',
                                      'image_id',
                                      'label',
                                      'metric_name',
                                      'reducer',
                                      'metric_score'
  ])
  file_name = f'{MODEL_NAME}_results.csv'
  res.to_csv(file_name)

  # !gsutil cp {file_name} gs://{bucket_name}/
  # !gsutil -m cp -r explanations gs://{bucket_name}/ 

  print('\n\n\n Done for ', MODEL_NAME, '\n\n\n')
# Out:
# clipRN50
# 100%|███████████████████████████████████████| 244M/244M [00:04<00:00, 63.4MiB/s]
# 100%|██████████| 1000/1000 [1:21:49<00:00,  4.91s/it]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-68ca16cc4e0e> in <module>()
#      10   modelclip = getattr(zoo, MODEL_NAME)(MODEL_NAME)
#      11   zeroshot_weights = modelclip.zeroshot_weights
# ---> 12   model = modelclip.model.cuda()
#      13
#      14   get_ipython().system('rm -rf explanations')
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in cuda(self, device)
#     686             Module: self
#     687         """
# --> 688         return self._apply(lambda t: t.cuda(device))
#     689
#     690     def xpu(self: T, device: Optional[Union[int, device]] = None) -> T:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     576     def _apply(self, fn):
#     577         for module in self.children():
# --> 578             module._apply(fn)
#     579
#     580         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     576     def _apply(self, fn):
#     577         for module in self.children():
# --> 578             module._apply(fn)
#     579
#     580         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     599             # `with torch.no_grad():`
#     600             with torch.no_grad():
# --> 601                 param_applied = fn(param)
#     602             should_use_set_data = compute_should_use_set_data(param, param_applied)
#     603             if should_use_set_data:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in <lambda>(t)
#     686             Module: self
#     687         """
# --> 688         return self._apply(lambda t: t.cuda(device))
#     689
#     690     def xpu(self: T, device: Optional[Union[int, device]] = None) -> T:
#
# /usr/local/lib/python3.7/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     214         # This function throws if there's a driver initialization error, no GPUs
#     215         # are found or any other error occurs
# --> 216         torch._C._cuda_init()
#     217         # Some of the queued calls may reentrantly call _lazy_init();
#     218         # we need to just return without initializing in that case.
#
# RuntimeError: No CUDA GPUs are available

# %%
import pandas as pd

bucket_name = "serrelab/prj_metapredictor"
# !gsutil cp results.csv gs://{bucket_name}/

res = pd.DataFrame(RESULTS, columns=[
                                     'model name', 
                                     'attribution name',
                                     'image_id',
                                     'label',
                                     'metric_name',
                                     'reducer',
                                     'metric_score'
])

res.to_csv('results.csv')

# %%
# !gsutil -m cp -r explanations gs://{bucket_name}/

# %%
zoo = modelvshuman.models.pytorch.model_zoo
for model_name in models.list_models("pytorch"):
  if 'transformer' in model_name:
    continue
  if 'vit' in model_name:
    continue
  if 'BiTM' in model_name:
    continue
  try:
    model = getattr(zoo, model_name)(model_name)
    model = model.model
    gc_layer = find_last_conv_layer(model)
    gc_explainer = LayerGradCam(model, gc_layer)

    gc_phi = gc_explainer.attribute(x_batch.cpu(), torch.argmax(y_batch, axis=-1))
    print(model_name, 'loaded', gc_phi.shape)
    print('\n\n')
  except Exception as e:
    print('\n /!\ ERROR FOR ', model_name, ': ', e, '  /!\  \n\n')
    print(e)
